# %% [markdown]
# # hypo-2 노령화 지수가 높은 곳일수록 전통시장, 공원 등 주요 문화시설이 많을 것이다.

# %% [markdown]
# ## require library install

# %%
# !pip install folium
# !pip install googlemaps
# !pip install openpyxl
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ### library import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import googlemaps
import seaborn as sns
from matplotlib import rc
import os

if os.name == 'nt':
    print("This is a Windows environment.")
    rc('font', family='Malgun Gothic') 

elif os.name == 'posix':
    print("This is a Mac or Linux environment.")
    rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# This is a Mac or Linux environment.

# %% [markdown]
# ## data import

# %%
# 노령화 지수
old_point = pd.read_excel('./data/자치구별+노령화지수(추계인구)_20240929181758.xlsx')
old_point.head()
# Out:
#    자치구별(1)  자치구별(2)   2023 2023.1 2023.2
# 0  자치구별(1)  자치구별(2)     합계     남자     여자
# 1       합계       소계  199.1  171.6  228.2
# 2      NaN      종로구  267.8  237.3    298
# 3      NaN       중구  286.5  245.3  329.3
# 4      NaN      용산구  200.7  172.2    230

# %%
old_pop = pd.read_excel('./data/자치구별+연령계층별+인구구성비(추계인구)_20241108190613.xlsx')
old_pop.head()
# Out:
#    자치구별(1)   2023  2023.1 2023.2
# 0  자치구별(1)  유소년인구  생산가능인구   고령인구
# 1       합계    9.1    72.8   18.1
# 2      종로구      7    74.1   18.9
# 3       중구    6.8    73.6   19.6
# 4      용산구    8.6    74.1   17.3

# %%
# 공원, 전통시장 등
park = pd.read_csv('./data/KC_ODSN_WALK_RECOMEND_LIST_2023.csv')
park.head()
# Out:
#               ESNTL_ID LCLAS_NM   MLSFC_NM FCLTY_NM  CTPRVN_CD CTPRVN_NM  \
# 0  KCOWRPO23N000000001     쇼핑시설  쇼핑시설_전통시장   원미부흥시장         41       경기도
# 1  KCOWRPO23N000000002     쇼핑시설  쇼핑시설_전통시장   원미종합시장         41       경기도
# 2  KCOWRPO23N000000003       자연      자연_공원     원미별빛         41       경기도
# 3  KCOWRPO23N000000004       자연      자연_공원       원미         41       경기도
# 4  KCOWRPO23N000000005     쇼핑시설  쇼핑시설_전통시장     음성시장         43      충청북도
#
#    SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# 0      41190   부천시 원미구    4119010100          원미동  ...
# 1      41190   부천시 원미구    4119010100          원미동  ...
# 2      41190   부천시 원미구    4119010100          원미동  ...
# 3      41190   부천시 원미구    4119010100          원미동  ...
# 4      43770       음성군    4377025021          읍내리  ...
#
#               BULD_MANAGE_CD TEL_NO   ZIP_NO HMPG_URL   FCLTY_LA    FCLTY_LO  \
# 0  4119510100101180000000000    0.0  14571.0      0.0  37.553516  126.921715
# 1  4119510100100970000000000    0.0  14568.0      0.0  37.545392  126.953319
# 2  4119510100101270000000000    0.0  14571.0      0.0  37.491966  126.787309
# 3  4119510100100150000000000    0.0  14659.0      0.0  37.497985  126.799040
# 4  4377025021102490000000000    0.0  27697.0      0.0  36.938166  127.692127
#
#   ORIGIN_NM  ADIT_DC   UPDT_DT  REGIST_DT
# 0     공공데이터      상설장  20231231   20231231
# 1     공공데이터      상설장  20231231   20231231
# 2     공공데이터        -  20231231   20231231
# 3     공공데이터        -  20231231   20231231
# 4     공공데이터      5일장  20231231   20231231
#
# [5 rows x 26 columns]

# %%
# 문화시설 (복지관 등)

culture = pd.read_csv('./data/KC_485_DMSTC_MCST_OLDLSR_2023.csv')
culture.head()
# Out:
#                        ID LCLAS_NM MLSFC_NM       FCLTY_NM CTPRVN_NM  \
# 0  KC485PC23N000000000001     문화시설      복지관     1004가족복지센터      전라북도
# 1  KC485PC23N000000000002     문화시설      복지관   1004가족재가복지센터       경기도
# 2  KC485PC23N000000000003     문화시설      복지관  1004엔젤스방문요양센터       경기도
# 3  KC485PC23N000000000004     문화시설      복지관   100세고성재가복지센터      경상남도
# 4  KC485PC23N000000000005     문화시설      복지관     100세노인복지센터      경상남도
#
#   SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM   ADSTRD_CD ADSTRD_NM  ...    FCLTY_LO  \
# 0       익산시    5214011400        모현동1가  5214061000       모현동  ...  126.946306
# 1       화성시    4159025325      봉담읍 와우리  4159025300       봉담읍  ...  126.972771
# 2  고양시 일산서구    4128710500          덕이동  4128760000       덕이동  ...  126.751049
# 3       고성군    4882025021      고성읍 성내리  4882025000       고성읍  ...  128.321049
# 4       진주시    4817012500          신안동  4817071500       신안동  ...  128.071955
#
#     FCLTY_LA  OPER_INSTT_NM TEL_NO         LC_LO         LC_LA  LAST_CHG_DE  \
# 0  35.949725            NaN    NaN  9.500649e+05  1.772699e+06     20240906
# 1  37.215112            NaN    NaN  9.532215e+05  1.913051e+06     20240906
# 2  37.699774            NaN    NaN  9.339764e+05  1.966954e+06     20240906
# 3  34.974063            NaN    NaN  1.074947e+06  1.664660e+06     20240906
# 4  35.185477            NaN    NaN  1.052074e+06  1.687947e+06     20240906
#
#    ORIGIN_NM                        FILE_NM   BASE_DE
# 0         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 1         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 2         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 3         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 4         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
#
# [5 rows x 24 columns]

# %%
tour = pd.read_csv('./data/RB_SR_TURIST_TURSM_INFO_20221231.csv')
tour.head()
# Out:
# /var/folders/76/295r32t542b3jtvsn34n34s00000gn/T/ipykernel_1105/3793178725.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   tour = pd.read_csv('./data/RB_SR_TURIST_TURSM_INFO_20221231.csv')
#   FLAG_NM   FCLTY_NM                       RDNMADR_NM CTPRVN_KLANG_NM  \
# 0  노인복지시설      새실경로당               김천시 새실길 18-3 (다수동)            경상북도
# 1  노인복지시설    각리3리경로당                  영덕군 병곡면 신평1길 24            경상북도
# 2    관광호텔  데이즈 호텔 명동                              NaN           서울특별시
# 3  노인복지시설    신도2리경로당                  청도군 청도읍 신도1길 49            경상북도
# 4  노인복지시설      국제경로당  부산광역시  연제구 연수로 184(연산3동, 국제아파트)           부산광역시
#
#   SIGNGU_KLANG_NM     CTPRVN_ENG_NM SIGNGU_ENG_NM CTPRVN_CHNLNG_NM  \
# 0             김천시  Gyeongsangbuk-do    Gimcheonsi             慶尙北道
# 1             영덕군  Gyeongsangbuk-do  Yeongdeokgun             慶尙北道
# 2              중구             Seoul        Junggu            首爾特別市
# 3             청도군  Gyeongsangbuk-do   Cheongdogun             慶尙北道
# 4             연제구             Busan      Yeonjegu            釜山廣域市
#
#   SIGNGU_CHNLNG_NM CTPRVN_JLANG_NM SIGNGU_JLANG_NM  CTPRVN_CD  SIGNGU_CD  \
# 0              金泉市  慶?北道（キョンサンブクト)     金泉市(キムチョンシ)         37      37030
# 1              盈德郡  慶?北道（キョンサンブクト)     盈?郡（ヨンドクグン）         37      37350
# 2               中區          ソウル特別市        中?（チュング）         11      11020
# 3              淸道郡  慶?北道（キョンサンブクト)     ?道郡（チョンドグン）         37      37360
# 4              蓮堤區      釜山（プサン）?域市      蓮堤?（ヨンジェグ）         21      21130
#
#      FCLTY_LO   FCLTY_LA HMPG_URL  TEL_NO  REGIST_DE
# 0  129.471868  42.909408      NaN     NaN   20221231
# 1  129.471868  42.909408      NaN     NaN   20221231
# 2  123.431472  41.805699      NaN     NaN   20221231
# 3  123.431472  41.805699      NaN     NaN   20221231
# 4  128.573767  38.194816      NaN     NaN   20221231

# %%
area = pd.read_excel('./data/행정구역(구별)_20241014164019.xlsx')
area.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %% [markdown]
# ## preprocessing

# %% [markdown]
# ### old_point

# %%
old_point.drop(index=[0, 1], columns=["자치구별(1)"], inplace=True)
old_point.columns = ['구별', '합계', '남자', '여자']
old_point.reset_index(drop=True, inplace=True)
old_point.head()
# Out:
#     구별     합계     남자     여자
# 0  종로구  267.8  237.3    298
# 1   중구  286.5  245.3  329.3
# 2  용산구  200.7  172.2    230
# 3  성동구  193.4  167.5  219.9
# 4  광진구  211.1  183.7  240.1

# %% [markdown]
# ### old_pop

# %%
old_pop.drop(index=[0, 1], inplace=True)
old_pop.columns = ['구별', '유소년인구', '생산가능인구', '고령인구']
old_pop.reset_index(drop=True, inplace=True)
old_pop.head()
# Out:
#     구별 유소년인구 생산가능인구  고령인구
# 0  종로구     7   74.1  18.9
# 1   중구   6.8   73.6  19.6
# 2  용산구   8.6   74.1  17.3
# 3  성동구   8.9   73.8  17.3
# 4  광진구   7.7   76.1  16.2

# %% [markdown]
# ### park

# %%
park = park[park['CTPRVN_NM'].str.contains('서울')]
park.head()
# Out:
#                ESNTL_ID LCLAS_NM MLSFC_NM FCLTY_NM  CTPRVN_CD CTPRVN_NM  \
# 34  KCOWRPO23N000000035       자연    자연_공원     효  성         11     서울특별시
# 35  KCOWRPO23N000000036       자연    자연_공원      등나무         11     서울특별시
# 36  KCOWRPO23N000000037       자연    자연_공원       마들          0        서울
# 37  KCOWRPO23N000000038       자연    자연_공원     매  봉         11     서울특별시
# 38  KCOWRPO23N000000039       자연    자연_공원     벼  루         11     서울특별시
#
#     SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# 34      11350       노원구    1135010300          공릉동  ...
# 35      11350       노원구    1135010600          중계동  ...
# 36          0       노원구             0          상계동  ...
# 37      11350       노원구    1135010200          월계동  ...
# 38      11350       노원구    1135010200          월계동  ...
#
#                BULD_MANAGE_CD TEL_NO   ZIP_NO HMPG_URL   FCLTY_LA    FCLTY_LO  \
# 34  1135010300107420000000000    0.0   1804.0      0.0  37.621233  127.087753
# 35  1135010600105080000000000    0.0   1783.0      0.0  37.640661  127.066866
# 36                        NaN    0.0  14567.0      0.0  37.644873  127.058305
# 37  1135010200103200000000000    0.0   1865.0      0.0  37.633234  127.059006
# 38  1135010200104970000000000    0.0   1890.0      0.0  37.619240  127.056545
#
#    ORIGIN_NM  ADIT_DC   UPDT_DT  REGIST_DT
# 34     공공데이터        -  20231231   20231231
# 35     공공데이터        -  20231231   20231231
# 36     공공데이터        -  20231231   20231231
# 37     공공데이터        -  20231231   20231231
# 38     공공데이터        -  20231231   20231231
#
# [5 rows x 26 columns]

# %%
park.drop(columns=['ESNTL_ID', 'CTPRVN_CD', 'SIGNGU_CD', 'LEGALDONG_CD', 'ROAD_NM_CD' , 'TEL_NO', 'ZIP_NO',
                   'LEGALDONG_NM', 'ADDR_ENG_NM', 'ADSTRD_CD', 'BULD_NM', 'BULD_MANAGE_CD', 'HMPG_URL', 'ORIGIN_NM', 'ADIT_DC',
                   'UPDT_DT', 'REGIST_DT'], inplace=True)
park.reset_index(drop=True, inplace=True)
park.head()
# Out:
#   LCLAS_NM MLSFC_NM FCLTY_NM CTPRVN_NM SIGNGU_NM  \
# 0       자연    자연_공원     효  성     서울특별시       노원구
# 1       자연    자연_공원      등나무     서울특별시       노원구
# 2       자연    자연_공원       마들        서울       노원구
# 3       자연    자연_공원     매  봉     서울특별시       노원구
# 4       자연    자연_공원     벼  루     서울특별시       노원구
#
#                FCLTY_ROAD_NM_ADDR                          LNM_ADDR  \
# 0  서울특별시 노원구 화랑로 556 (공릉동, 효성아파트)           서울특별시 노원구 공릉동 742 효성아파트
# 1        서울특별시 노원구 동일로 1238 (중계동)     서울특별시 노원구 중계동 508 서울시립 북서울미술관
# 2               서울특별시 노원구 덕릉로 450                  서울 노원구 상계동 770-2
# 3       서울특별시 노원구 월계로55길 49 (월계동)               서울특별시 노원구 월계동 320-6
# 4        서울특별시 노원구 광운로1길 24 (월계동)  서울특별시 노원구 월계동 500 광운중/광운인공지능고등학교
#
#     FCLTY_LA    FCLTY_LO
# 0  37.621233  127.087753
# 1  37.640661  127.066866
# 2  37.644873  127.058305
# 3  37.633234  127.059006
# 4  37.619240  127.056545

# %%
park['MLSFC_NM'].value_counts()
# Out:
# MLSFC_NM
# 자연_공원        1621
# 쇼핑시설_전통시장     219
# 무장애_나눔길         3
# Name: count, dtype: int64

# %%
park['LCLAS_NM'].value_counts()
# Out:
# LCLAS_NM
# 자연       1621
# 쇼핑시설      219
# 무장애장소       3
# Name: count, dtype: int64

# %% [markdown]
# ### culture

# %%
culture = culture[culture['CTPRVN_NM'].str.contains('서울')]
culture.head()
# Out:
#                          ID LCLAS_NM  MLSFC_NM      FCLTY_NM CTPRVN_NM  \
# 17   KC485PC23N000000000018     문화시설       복지관     1318상상발전소     서울특별시
# 18   KC485PC23N000000000019     문화시설       복지관       1318해피존     서울특별시
# 29   KC485PC23N000000000030     문화시설       복지관   153재가장기요양기관     서울특별시
# 71   KC485PC23N000000000072     문화시설  노인정/노인회관     3단지아파트노인정     서울특별시
# 102  KC485PC23N000000000103     문화시설       복지관  99팔팔재가노인복지센터     서울특별시
#
#     SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM   ADSTRD_CD ADSTRD_NM  ...  \
# 17        중랑구    1126010400           묵동  1126063000       묵2동  ...
# 18        용산구    1117012800        한강로3가  1117062500      한강로동  ...
# 29        중랑구    1126010100          면목동  1126057000      면목7동  ...
# 71        강서구    1150010400          가양동  1150060400      가양2동  ...
# 102       강서구    1150010300          화곡동  1150059100      화곡6동  ...
#
#        FCLTY_LO   FCLTY_LA  OPER_INSTT_NM TEL_NO          LC_LO         LC_LA  \
# 17   127.077072  37.606135            NaN    NaN  962670.272236  1.956385e+06
# 18   126.956555  37.531929            NaN    NaN  951985.086624  1.948207e+06
# 29   127.083549  37.578477            NaN    NaN  963228.320845  1.953314e+06
# 71   126.856279  37.564612            NaN    NaN  943150.174500  1.951889e+06
# 102  126.854230  37.554832            NaN    NaN  942961.762211  1.950805e+06
#
#      LAST_CHG_DE  ORIGIN_NM                        FILE_NM   BASE_DE
# 17      20240906         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 18      20240906         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 29      20240906         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 71      20240906         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
# 102     20240906         KT  KC_485_DMSTC_MCST_OLDLSR_2023  20231231
#
# [5 rows x 24 columns]

# %%
culture.drop(columns=['ID', 'LEGALDONG_CD', 'OPER_INSTT_NM', 'TEL_NO', "ORIGIN_NM", "LAST_CHG_DE", "FILE_NM",
                        'BASE_DE', 'LCLAS_NM', 'ADSTRD_CD', 'LEGALDONG_NM', 'RDNMADR_CD', 'ADSTRD_NM', 'GID_CD', 
                        "ZIP_NO", "LC_LO", "LC_LA"], inplace=True)
culture.reset_index(drop=True, inplace=True)
culture.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
culture['MLSFC_NM'].value_counts()
# Out:
# MLSFC_NM
# 노인정/노인회관    1492
# 복지관         1195
# 보육원/양로원      318
# 마을/새마을회관      51
# Name: count, dtype: int64

# %% [markdown]
# ### tour

# %%
tour.head()
# Out:
#   FLAG_NM   FCLTY_NM                       RDNMADR_NM CTPRVN_KLANG_NM  \
# 0  노인복지시설      새실경로당               김천시 새실길 18-3 (다수동)            경상북도
# 1  노인복지시설    각리3리경로당                  영덕군 병곡면 신평1길 24            경상북도
# 2    관광호텔  데이즈 호텔 명동                              NaN           서울특별시
# 3  노인복지시설    신도2리경로당                  청도군 청도읍 신도1길 49            경상북도
# 4  노인복지시설      국제경로당  부산광역시  연제구 연수로 184(연산3동, 국제아파트)           부산광역시
#
#   SIGNGU_KLANG_NM     CTPRVN_ENG_NM SIGNGU_ENG_NM CTPRVN_CHNLNG_NM  \
# 0             김천시  Gyeongsangbuk-do    Gimcheonsi             慶尙北道
# 1             영덕군  Gyeongsangbuk-do  Yeongdeokgun             慶尙北道
# 2              중구             Seoul        Junggu            首爾特別市
# 3             청도군  Gyeongsangbuk-do   Cheongdogun             慶尙北道
# 4             연제구             Busan      Yeonjegu            釜山廣域市
#
#   SIGNGU_CHNLNG_NM CTPRVN_JLANG_NM SIGNGU_JLANG_NM  CTPRVN_CD  SIGNGU_CD  \
# 0              金泉市  慶?北道（キョンサンブクト)     金泉市(キムチョンシ)         37      37030
# 1              盈德郡  慶?北道（キョンサンブクト)     盈?郡（ヨンドクグン）         37      37350
# 2               中區          ソウル特別市        中?（チュング）         11      11020
# 3              淸道郡  慶?北道（キョンサンブクト)     ?道郡（チョンドグン）         37      37360
# 4              蓮堤區      釜山（プサン）?域市      蓮堤?（ヨンジェグ）         21      21130
#
#      FCLTY_LO   FCLTY_LA HMPG_URL  TEL_NO  REGIST_DE
# 0  129.471868  42.909408      NaN     NaN   20221231
# 1  129.471868  42.909408      NaN     NaN   20221231
# 2  123.431472  41.805699      NaN     NaN   20221231
# 3  123.431472  41.805699      NaN     NaN   20221231
# 4  128.573767  38.194816      NaN     NaN   20221231

# %%
tour.drop(columns=['CTPRVN_ENG_NM', 'SIGNGU_ENG_NM', 'CTPRVN_CHNLNG_NM', 'SIGNGU_CHNLNG_NM',
                   'CTPRVN_JLANG_NM', 'SIGNGU_JLANG_NM', 'CTPRVN_CD', 'SIGNGU_CD', 'HMPG_URL', 'TEL_NO', 'REGIST_DE'], inplace=True)
tour.head()
# Out:
#   FLAG_NM   FCLTY_NM                       RDNMADR_NM CTPRVN_KLANG_NM  \
# 0  노인복지시설      새실경로당               김천시 새실길 18-3 (다수동)            경상북도
# 1  노인복지시설    각리3리경로당                  영덕군 병곡면 신평1길 24            경상북도
# 2    관광호텔  데이즈 호텔 명동                              NaN           서울특별시
# 3  노인복지시설    신도2리경로당                  청도군 청도읍 신도1길 49            경상북도
# 4  노인복지시설      국제경로당  부산광역시  연제구 연수로 184(연산3동, 국제아파트)           부산광역시
#
#   SIGNGU_KLANG_NM    FCLTY_LO   FCLTY_LA
# 0             김천시  129.471868  42.909408
# 1             영덕군  129.471868  42.909408
# 2              중구  123.431472  41.805699
# 3             청도군  123.431472  41.805699
# 4             연제구  128.573767  38.194816

# %%
tour = tour[tour['CTPRVN_KLANG_NM'].str.contains('서울')]
tour.reset_index(drop=True, inplace=True)
tour.head()
# Out:
#   FLAG_NM   FCLTY_NM             RDNMADR_NM CTPRVN_KLANG_NM SIGNGU_KLANG_NM  \
# 0    관광호텔  데이즈 호텔 명동                    NaN           서울특별시              중구
# 1  노인복지시설   한신아파트경로당   서울특별시 도봉구 도봉동 30-1번지           서울특별시             도봉구
# 2  노인복지시설      하계경로당  서울특별시 노원구 하계동 65-41번지           서울특별시             노원구
# 3  노인복지시설   서원아파트경로당   서울특별시 도봉구 도봉동 18-2번지           서울특별시             도봉구
# 4  노인복지시설   서광아파트경로당    서울특별시 도봉구 도봉동 643번지           서울특별시             도봉구
#
#      FCLTY_LO   FCLTY_LA
# 0  123.431472  41.805699
# 1  127.041248  37.690244
# 2  127.049245  37.689957
# 3  127.042773  37.688896
# 4  127.048673  37.687664

# %%
tour['FLAG_NM'].value_counts()
# Out:
# FLAG_NM
# 노인복지시설    3749
# 관광호텔       333
# 호스텔         96
# 가족호텔        21
# 소형호텔        10
# 벚꽃축제         2
# Name: count, dtype: int64

# %% [markdown]
# ### area

# %%
area.head()
# Out:
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %%
area.drop(columns='자치구별(1)', index=[0,2], inplace=True)
area.columns = area.loc[1, :]
area.drop(index=1, inplace=True)
area.reset_index(drop=True, inplace=True)
area.head()
# Out:
# 1 자치구별(2) 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0     종로구    23.91    3.95  17  87  279  1475
# 1      중구     9.96    1.65  15  74  253  1582
# 2     용산구    21.87    3.61  16  36  357  2601
# 3     성동구    16.82    2.78  17  17  471  3645
# 4     광진구    17.06    2.82  15   7  370  3012

# %%
area.rename(columns={"자치구별(2)" : '구별'}, inplace=True)
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0  종로구    23.91    3.95  17  87  279  1475
# 1   중구     9.96    1.65  15  74  253  1582
# 2  용산구    21.87    3.61  16  36  357  2601
# 3  성동구    16.82    2.78  17  17  471  3645
# 4  광진구    17.06    2.82  15   7  370  3012

# %%
area = area[['구별', '면적 (km²)', '구성비 (%)']]

# %% [markdown]
# ### merge to culture & tour

# %%
print(f"culture_seoul_dataframe rows = {culture.shape[0]}")
print(f"tour_seoul_dataframe rows = {tour.shape[0]}")
# Out:
# culture_seoul_dataframe rows = 3056
# tour_seoul_dataframe rows = 4211

# %%
culture.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
culture[culture['RDNMADR_NM'].str.contains('번지')]
# Out:
# Empty DataFrame
# Columns: [MLSFC_NM, FCLTY_NM, CTPRVN_NM, SIGNGU_NM, RDNMADR_NM, FCLTY_LO, FCLTY_LA]
# Index: []

# %%
tour = tour[tour['FLAG_NM'] == '노인복지시설']
tour.reset_index(drop=True, inplace=True)
tour.head()
# Out:
#   FLAG_NM  FCLTY_NM              RDNMADR_NM CTPRVN_KLANG_NM SIGNGU_KLANG_NM  \
# 0  노인복지시설  한신아파트경로당    서울특별시 도봉구 도봉동 30-1번지           서울특별시             도봉구
# 1  노인복지시설     하계경로당   서울특별시 노원구 하계동 65-41번지           서울특별시             노원구
# 2  노인복지시설  서원아파트경로당    서울특별시 도봉구 도봉동 18-2번지           서울특별시             도봉구
# 3  노인복지시설  서광아파트경로당     서울특별시 도봉구 도봉동 643번지           서울특별시             도봉구
# 4  노인복지시설     약수경로당  서울특별시 도봉구 도봉동 454-14번지           서울특별시             도봉구
#
#      FCLTY_LO   FCLTY_LA
# 0  127.041248  37.690244
# 1  127.049245  37.689957
# 2  127.042773  37.688896
# 3  127.048673  37.687664
# 4  127.041647  37.686535

# %%
tour.rename(columns={'FLAG_NM' : "MLSFC_NM", "CTPRVN_KLANG_NM" : "CTPRVN_NM", "SIGNGU_KLANG_NM":"SIGNGU_NM"}, inplace=True)
tour.head()
# Out:
#   MLSFC_NM  FCLTY_NM              RDNMADR_NM CTPRVN_NM SIGNGU_NM    FCLTY_LO  \
# 0   노인복지시설  한신아파트경로당    서울특별시 도봉구 도봉동 30-1번지     서울특별시       도봉구  127.041248
# 1   노인복지시설     하계경로당   서울특별시 노원구 하계동 65-41번지     서울특별시       노원구  127.049245
# 2   노인복지시설  서원아파트경로당    서울특별시 도봉구 도봉동 18-2번지     서울특별시       도봉구  127.042773
# 3   노인복지시설  서광아파트경로당     서울특별시 도봉구 도봉동 643번지     서울특별시       도봉구  127.048673
# 4   노인복지시설     약수경로당  서울특별시 도봉구 도봉동 454-14번지     서울특별시       도봉구  127.041647
#
#     FCLTY_LA
# 0  37.690244
# 1  37.689957
# 2  37.688896
# 3  37.687664
# 4  37.686535

# %% [markdown]
# #### merge

# %%
culture.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
tour.head()
# Out:
#   MLSFC_NM  FCLTY_NM              RDNMADR_NM CTPRVN_NM SIGNGU_NM    FCLTY_LO  \
# 0   노인복지시설  한신아파트경로당    서울특별시 도봉구 도봉동 30-1번지     서울특별시       도봉구  127.041248
# 1   노인복지시설     하계경로당   서울특별시 노원구 하계동 65-41번지     서울특별시       노원구  127.049245
# 2   노인복지시설  서원아파트경로당    서울특별시 도봉구 도봉동 18-2번지     서울특별시       도봉구  127.042773
# 3   노인복지시설  서광아파트경로당     서울특별시 도봉구 도봉동 643번지     서울특별시       도봉구  127.048673
# 4   노인복지시설     약수경로당  서울특별시 도봉구 도봉동 454-14번지     서울특별시       도봉구  127.041647
#
#     FCLTY_LA
# 0  37.690244
# 1  37.689957
# 2  37.688896
# 3  37.687664
# 4  37.686535

# %%
culture.shape, tour.shape
# Out:
# ((3056, 7), (3749, 7))

# %%
facility = pd.concat([culture, tour], ignore_index=True)
facility.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
facility.drop_duplicates(inplace=True)
facility.reset_index(drop=True, inplace=True)
facility.shape
# Out:
# (6796, 7)

# %%
facility.head()
# Out:
#    MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM                  RDNMADR_NM  \
# 0       복지관     1318상상발전소     서울특별시       중랑구       서울특별시 중랑구 묵동 중랑역로 142
# 1       복지관       1318해피존     서울특별시       용산구      서울특별시 용산구 한강로3가 청파로 46
# 2       복지관   153재가장기요양기관     서울특별시       중랑구  서울특별시 중랑구 면목동 사가정로46가길 3-5
# 3  노인정/노인회관     3단지아파트노인정     서울특별시       강서구       서울특별시 강서구 가양동 허준로 139
# 4       복지관  99팔팔재가노인복지센터     서울특별시       강서구      서울특별시 강서구 화곡동 공항대로 426
#
#      FCLTY_LO   FCLTY_LA
# 0  127.077072  37.606135
# 1  126.956555  37.531929
# 2  127.083549  37.578477
# 3  126.856279  37.564612
# 4  126.854230  37.554832

# %%
# null 값 63행 확인
facility[facility['FCLTY_LO'].isna() | facility['FCLTY_LA'].isna()]
# Out:
#      MLSFC_NM     FCLTY_NM CTPRVN_NM SIGNGU_NM  \
# 6733   노인복지시설     대청3단지경로당     서울특별시       강남구
# 6734   노인복지시설        포이경로당     서울특별시       강남구
# 6735   노인복지시설  개포3단지(아)경로당     서울특별시       강남구
# 6736   노인복지시설        개포경로당     서울특별시       강남구
# 6737   노인복지시설        이화경로당     서울특별시       강남구
# ...       ...          ...       ...       ...
# 6791   노인복지시설     삼부아파트경로당     서울특별시       성동구
# 6792   노인복지시설  행당한신 제2 경로당     서울특별시       성동구
# 6793   노인복지시설    명륜2,4가경로당     서울특별시       종로구
# 6794   노인복지시설    종로5,6가경로당     서울특별시       종로구
# 6795   노인복지시설  두산4,5단지 경로당     서울특별시       중랑구
#
#                            RDNMADR_NM  FCLTY_LO  FCLTY_LA
# 6733                    서울특별시 강남구 개포동       NaN       NaN
# 6734                    서울특별시 강남구 개포동       NaN       NaN
# 6735              서울특별시 강남구 개포동 138번지       NaN       NaN
# 6736            서울특별시 강남구 개포동 169-3번지       NaN       NaN
# 6737              서울특별시 강남구 개포동 181번지       NaN       NaN
# ...                               ...       ...       ...
# 6791              서울특별시 성동구 행당동 147번지       NaN       NaN
# 6792  서울특별시 성동구 행당동 201 201동 105,106호       NaN       NaN
# 6793           서울특별시 종로구 명륜4가 206-8번지       NaN       NaN
# 6794            서울특별시 종로구 효제동 173-2번지       NaN       NaN
# 6795             서울특별시 중랑구 면목동 1522번지       NaN       NaN
#
# [63 rows x 7 columns]

# %% [markdown]
# #### api

# %% [markdown]
# * https://developers.kakao.com/docs/latest/ko/local/dev-guide#address-coord

# %%
import requests
import json

def convert_address(address):
    
    path = '/v2/local/search/address.json'
    api_host = 'https://dapi.kakao.com'
    api_key = '275fa9c9b83625900bee1dc000fd7dcb'
    url = api_host+path
    
    header = {
        "Authorization" : f'KakaoAK {api_key}'
    }
    
    body = {
    "format" : "json",
    'query' : address
    }

    try:
        response = requests.get(url=url, params=body, headers=header, timeout=10)  # 10초 타임아웃
        response.raise_for_status()  # HTTP 오류가 발생하면 예외 발생
    except requests.exceptions.Timeout:
        print("Request timed out")
        return {}
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return {}

    parsed_data = json.loads(response.text)

    return parsed_data

# %%
parsed_data = convert_address('서울특별시 강서구 화곡동 공항대로 426')

# %%
# road_address
parsed_data['documents'][0]['road_address']['address_name']
# Out:
# '서울 강서구 공항대로 426'

# %%
# x position
parsed_data['documents'][0]['road_address']['x']
# Out:
# '126.854229652711'

# %%
# y position
parsed_data['documents'][0]['road_address']['y']
# Out:
# '37.5548319100792'

# %%
facility.iloc[44]
# Out:
# MLSFC_NM                     노인정/노인회관
# FCLTY_NM                       가리봉경로당
# CTPRVN_NM                       서울특별시
# SIGNGU_NM                         구로구
# RDNMADR_NM    서울특별시 구로구 가리봉동 우마1다길 25
# FCLTY_LO                   126.889745
# FCLTY_LA                    37.482934
# Name: 44, dtype: object

# %%
addr_list = []
x_list = []
y_list = []
null_indexs = {
    'addr_idx' : [],
    'x_idx' : [],
    'y_idx' : []
}
for idx, val in facility.iterrows():
    data = val['RDNMADR_NM']
    parsed_data = convert_address(data)
    try:
        addr = parsed_data['documents'][0]['road_address']['address_name']
    except:
        addr = val['RDNMADR_NM']
        null_indexs['addr_idx'].append(idx)
    try:
        x = parsed_data['documents'][0]['road_address']['x']
    except:
        x = val['FCLTY_LO']
        null_indexs['x_idx'].append(idx)
    try:
        y = parsed_data['documents'][0]['road_address']['y']
    except:
        y = val['FCLTY_LA']
        null_indexs['y_idx'].append(idx)
        
    addr_list.append(addr)
    x_list.append(x)
    y_list.append(y)

# %%
len(null_indexs['addr_idx']), len(null_indexs['x_idx']), len(null_indexs['y_idx'])
# Out:
# (1163, 1163, 1163)

# %%
len(addr_list)
# Out:
# 6796

# %%
same_idx = (null_indexs['addr_idx'] == null_indexs['x_idx'] == null_indexs['y_idx'])
same_idx
# Out:
# True

# %%
addr_list[-5:], x_list[-5:], y_list[-5:]
# Out:
# (['서울 성동구 왕십리로 278-17',
#   '서울특별시 성동구 행당동 201 201동 105,106호',
#   '서울 종로구 창경궁로26길 7',
#   '서울 종로구 종로35가길 19',
#   '서울 중랑구 면목로35길 63'],
#  ['127.037851167361',
#   nan,
#   '126.998136394522',
#   '127.005031333474',
#   '127.081978831132'],
#  ['37.5592483612854',
#   nan,
#   '37.5818949849387',
#   '37.5720611697886',
#   '37.5785997107848'])

# %%
facility['RDNMADR_NM'] = addr_list
facility['FCLTY_LO'] = x_list
facility['FCLTY_LA'] = y_list

facility.tail()
# Out:
#      MLSFC_NM     FCLTY_NM CTPRVN_NM SIGNGU_NM  \
# 6791   노인복지시설     삼부아파트경로당     서울특별시       성동구
# 6792   노인복지시설  행당한신 제2 경로당     서울특별시       성동구
# 6793   노인복지시설    명륜2,4가경로당     서울특별시       종로구
# 6794   노인복지시설    종로5,6가경로당     서울특별시       종로구
# 6795   노인복지시설  두산4,5단지 경로당     서울특별시       중랑구
#
#                            RDNMADR_NM          FCLTY_LO          FCLTY_LA
# 6791               서울 성동구 왕십리로 278-17  127.037851167361  37.5592483612854
# 6792  서울특별시 성동구 행당동 201 201동 105,106호               NaN               NaN
# 6793                 서울 종로구 창경궁로26길 7  126.998136394522  37.5818949849387
# 6794                 서울 종로구 종로35가길 19  127.005031333474  37.5720611697886
# 6795                 서울 중랑구 면목로35길 63  127.081978831132  37.5785997107848

# %%
facility2 = facility.iloc[null_indexs['addr_idx']]
facility2.head()
# Out:
#      MLSFC_NM                 FCLTY_NM CTPRVN_NM SIGNGU_NM  \
# 44   노인정/노인회관                   가리봉경로당     서울특별시       구로구
# 46   노인정/노인회관                가리봉제1동경로당     서울특별시       구로구
# 84   노인정/노인회관                    갈산경로당     서울특별시       양천구
# 116       복지관  강동구립장애인종합복지관(2024년3월예정)     서울특별시       강동구
# 225  노인정/노인회관                    계성경로당     서울특별시       도봉구
#
#                   RDNMADR_NM    FCLTY_LO   FCLTY_LA
# 44   서울특별시 구로구 가리봉동 우마1다길 25  126.889745  37.482934
# 46   서울특별시 구로구 가리봉동 우마1다길 25  126.889678  37.482897
# 84             서울특별시 양천구 신정동  126.854354  37.518553
# 116            서울특별시 강동구 천호동  127.128669  37.542222
# 225            서울특별시 도봉구 쌍문동  127.029191  37.651319

# %% [markdown]
# #### api 2

# %% [markdown]
# https://developers.kakao.com/docs/latest/ko/local/dev-guide#coord-to-address

# %% [markdown]
# https://dapi.kakao.com/v2/local/geo/coord2address.${FORMAT}

# %%
import requests
import json

def coord_to_address(lo, la, input_coord = 'WGS84'):
    
    path = '/v2/local/geo/coord2address.json'
    api_host = 'https://dapi.kakao.com'
    api_key = '275fa9c9b83625900bee1dc000fd7dcb'
    url = api_host+path
    
    header = {
        "Authorization" : f'KakaoAK {api_key}'
    }
    
    body = {
    "format" : "json",
    'x' : lo,
    'y' : la,
    'input_coord' : input_coord
    }

    try:
        response = requests.get(url=url, params=body, headers=header, timeout=10)  # 10초 타임아웃
        response.raise_for_status()  # HTTP 오류가 발생하면 예외 발생
    except requests.exceptions.Timeout:
        print("Request timed out")
        return {}
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return {}

    parsed_data = json.loads(response.text)

    return parsed_data

# %%
double_address_idx = []
addr2_list = []
null_indexs2 = []
none_indexs2 = []

for idx, val in facility2.iterrows():
    lo_x = val['FCLTY_LO']
    la_y = val['FCLTY_LA']
    
    if np.isnan(lo_x) or np.isnan(la_y):
        null_indexs2.append(idx)
        pass
        
    else:
        lo_x = round(lo_x, 6)
        la_y = round(la_y, 6)
        addr2 = val['RDNMADR_NM']
        parsed_data2 = coord_to_address(lo_x, la_y)
 
        if 'meta' in parsed_data2:
            total_count = parsed_data2['meta'].get('total_count', 0)

            if total_count == 0:
                null_indexs2.append(idx)

            elif total_count == 1:
                if parsed_data2['documents'][0].get('road_address', 0) == None:
                    none_indexs2.append(idx)
                    
                else:
                    addr2 = parsed_data2['documents'][0]['road_address']['address_name']
                    
            else:
                double_address_idx.append(idx)
                
        else:
            null_indexs2.append(idx)
                
    addr2_list.append(addr2)

# %%
len(double_address_idx), len(addr2_list), len(null_indexs2), len(none_indexs2)
# Out:
# (0, 1163, 31, 324)

# %%
addr2_list[:5], null_indexs2[:5], none_indexs2[:5]
# Out:
# (['서울특별시 구로구 우마1가길 13-9',
#   '서울특별시 구로구 우마1가길 13-9',
#   '서울특별시 양천구 중앙로32길 1',
#   '서울특별시 강동구 구천면로33길 43-7',
#   '서울특별시 도봉구 시루봉로 8'],
#  [5997, 5998, 6000, 6001, 6730],
#  [287, 289, 417, 449, 498])

# %%
facility.loc[null_indexs['addr_idx'], ['RDNMADR_NM']] = addr2_list
facility3 = facility.loc[(facility.index.isin(null_indexs2)) | (facility.index.isin(none_indexs2))]
facility3
# Out:
#       MLSFC_NM     FCLTY_NM CTPRVN_NM SIGNGU_NM                 RDNMADR_NM  \
# 287   노인정/노인회관     광진구용마경로당     서울특별시       광진구              서울특별시 광진구 중곡동
# 289   노인정/노인회관   광진구중곡4동경로당     서울특별시       광진구              서울특별시 광진구 중곡동
# 417   노인정/노인회관      구립웃말경로당     서울특별시       강동구  서울특별시 강동구 성내동 천호대로162길 72
# 449   노인정/노인회관   구립흑석제3동경로당     서울특별시       동작구   서울특별시 동작구 흑석동 서달로10다길 29
# 498   노인정/노인회관        금실경로당     서울특별시       양천구       서울특별시 양천구 신월동 지양로 21
# ...        ...          ...       ...       ...                        ...
# 6786    노인복지시설        삼개경로당     서울특별시       마포구              서울특별시 강남구 세곡동
# 6788    노인복지시설        쌈지경로당     서울특별시       마포구              서울특별시 강남구 세곡동
# 6789    노인복지시설        구룡경로당     서울특별시       마포구              서울특별시 강남구 세곡동
# 6790    노인복지시설       새마을경로당     서울특별시       마포구              서울특별시 강남구 세곡동
# 6792    노인복지시설  행당한신 제2 경로당     서울특별시       성동구              서울특별시 강남구 세곡동
#
#         FCLTY_LO   FCLTY_LA
# 287   127.090401  37.561748
# 289   127.090401  37.561748
# 417   127.127536   37.53374
# 449   126.963999  37.503997
# 498   126.837188  37.518461
# ...          ...        ...
# 6786         NaN        NaN
# 6788         NaN        NaN
# 6789         NaN        NaN
# 6790         NaN        NaN
# 6792         NaN        NaN
#
# [355 rows x 7 columns]

# %%
coord_to_address(127.090401, 37.561748)
# Out:
# {'meta': {'total_count': 1},
#  'documents': [{'road_address': None,
#    'address': {'address_name': '서울 광진구 중곡동 143-119',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '광진구',
#     'region_3depth_name': '중곡동',
#     'mountain_yn': 'N',
#     'main_address_no': '143',
#     'sub_address_no': '119',
#     'zip_code': ''}}]}

# %%
coord_to_address(126.889745, 37.482934)
# Out:
# {'meta': {'total_count': 1},
#  'documents': [{'road_address': {'address_name': '서울특별시 구로구 우마1가길 13-9',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '구로구',
#     'region_3depth_name': '',
#     'road_name': '우마1가길',
#     'underground_yn': 'N',
#     'main_building_no': '13',
#     'sub_building_no': '9',
#     'building_name': '가리봉1동 복지관',
#     'zone_no': '08383'},
#    'address': {'address_name': '서울 구로구 가리봉동 111-1',
#     'region_1depth_name': '서울',
#     'region_2depth_name': '구로구',
#     'region_3depth_name': '가리봉동',
#     'mountain_yn': 'N',
#     'main_address_no': '111',
#     'sub_address_no': '1',
#     'zip_code': ''}}]}

# %% [markdown]
# #### api 3

# %%
import requests
import json

def convert_name(name):
    
    path = '/v2/local/search/keyword.json'
    api_host = 'https://dapi.kakao.com'
    api_key = '275fa9c9b83625900bee1dc000fd7dcb'
    url = api_host+path
    
    header = {
        "Authorization" : f'KakaoAK {api_key}'
    }
    
    body = {
    "format" : "json",
    'query' : name
    }

    try:
        response = requests.get(url=url, params=body, headers=header, timeout=10)  # 10초 타임아웃
        response.raise_for_status()  # HTTP 오류가 발생하면 예외 발생
    except requests.exceptions.Timeout:
        print("Request timed out")
        return {}
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return {}

    parsed_data = json.loads(response.text)

    return parsed_data

# %%
convert_name('광진구용마경로당')
# Out:
# {'documents': [{'address_name': '서울 광진구 중곡동 169-81',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 친목 > 노인정,노인회',
#    'distance': '',
#    'id': '23888627',
#    'phone': '',
#    'place_name': '용마경로당',
#    'place_url': 'http://place.map.kakao.com/23888627',
#    'road_address_name': '',
#    'x': '127.08457311443',
#    'y': '37.5682896911163'},
#   {'address_name': '서울 중랑구 면목동 619-7',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 친목 > 노인정,노인회',
#    'distance': '',
#    'id': '24012527',
#    'phone': '',
#    'place_name': '면목7동구립용마경로당',
#    'place_url': 'http://place.map.kakao.com/24012527',
#    'road_address_name': '서울 중랑구 면목로40길 23',
#    'x': '127.088447735539',
#    'y': '37.5788465085427'},
#   {'address_name': '서울 중랑구 면목동 494',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 친목 > 노인정,노인회',
#    'distance': '',
#    'id': '10619017',
#    'phone': '',
#    'place_name': '용마금호어울림 노인회',
#    'place_url': 'http://place.map.kakao.com/10619017',
#    'road_address_name': '서울 중랑구 용마산로 348',
#    'x': '127.094321507768',
#    'y': '37.5828351643865'},
#   {'address_name': '서울 중랑구 망우동 산 69-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '가정,생활 > 친목 > 노인정,노인회',
#    'distance': '',
#    'id': '23998092',
#    'phone': '',
#    'place_name': '용마공원노인정',
#    'place_url': 'http://place.map.kakao.com/23998092',
#    'road_address_name': '서울 중랑구 용마산로112나길 69',
#    'x': '127.102463687938',
#    'y': '37.5958855548984'}],
#  'meta': {'is_end': True,
#   'pageable_count': 4,
#   'same_name': {'keyword': '용마경로당', 'region': [], 'selected_region': '서울 광진구'},
#   'total_count': 4}}

# %%
facility3.head()
# Out:
#      MLSFC_NM    FCLTY_NM CTPRVN_NM SIGNGU_NM                 RDNMADR_NM  \
# 287  노인정/노인회관    광진구용마경로당     서울특별시       광진구              서울특별시 광진구 중곡동
# 289  노인정/노인회관  광진구중곡4동경로당     서울특별시       광진구              서울특별시 광진구 중곡동
# 417  노인정/노인회관     구립웃말경로당     서울특별시       강동구  서울특별시 강동구 성내동 천호대로162길 72
# 449  노인정/노인회관  구립흑석제3동경로당     서울특별시       동작구   서울특별시 동작구 흑석동 서달로10다길 29
# 498  노인정/노인회관       금실경로당     서울특별시       양천구       서울특별시 양천구 신월동 지양로 21
#
#        FCLTY_LO   FCLTY_LA
# 287  127.090401  37.561748
# 289  127.090401  37.561748
# 417  127.127536   37.53374
# 449  126.963999  37.503997
# 498  126.837188  37.518461

# %%
facility3['FCLTY_NM']
# Out:
# 287        광진구용마경로당
# 289      광진구중곡4동경로당
# 417         구립웃말경로당
# 449      구립흑석제3동경로당
# 498           금실경로당
#            ...
# 6786          삼개경로당
# 6788          쌈지경로당
# 6789          구룡경로당
# 6790         새마을경로당
# 6792    행당한신 제2 경로당
# Name: FCLTY_NM, Length: 355, dtype: object

# %%
for idx, val in facility3.iterrows():
    print(idx, val)
    break
# Out:
# 287 MLSFC_NM           노인정/노인회관
# FCLTY_NM           광진구용마경로당
# CTPRVN_NM             서울특별시
# SIGNGU_NM               광진구
# RDNMADR_NM    서울특별시 광진구 중곡동
# FCLTY_LO         127.090401
# FCLTY_LA          37.561748
# Name: 287, dtype: object

# %%
val['FCLTY_NM']
# Out:
# '광진구용마경로당'

# %%
addr_list = []
x_list = []
y_list = []
name_list = []
null_list = []

for idx, val in facility3.iterrows():
    name = val['FCLTY_NM']
    convert = convert_name(name)

    if convert.get('documents') == []:
        null_list.append(idx)
        continue
    
    elif convert['documents'][0].get('road_address_name') == '':
        c_addr = convert['documents'][0].get('address_name')
        addr_list.append(c_addr)
    else:
        c_addr = convert['documents'][0].get('road_address_name')
        addr_list.append(c_addr)

    c_x = convert['documents'][0].get('x')
    c_y = convert['documents'][0].get('y')
    c_name = convert['documents'][0].get('place_name')

    x_list.append(x)
    y_list.append(y)
    name_list.append(c_name)
    

addr_list[:5], x_list[:5], y_list[:5], name_list[:5]
# Out:
# (['서울 광진구 중곡동 169-81',
#   '서울 광진구 긴고랑로39길 57',
#   '서울 성동구 독서당로47가길 16-19',
#   '부산 사하구 윤공단로 25-3',
#   '서울 성북구 삼양로2길 55'],
#  ['127.081978831132',
#   '127.081978831132',
#   '127.081978831132',
#   '127.081978831132',
#   '127.081978831132'],
#  ['37.5785997107848',
#   '37.5785997107848',
#   '37.5785997107848',
#   '37.5785997107848',
#   '37.5785997107848'],
#  ['용마경로당', '광진구중곡4동경로당', '성동구 구립 금강경로당', '기쁨재가복지센터', '길음데이케어센터'])

# %%
len(null_list)
# Out:
# 161

# %%
convert_name('50플러스 센터')
# Out:
# {'documents': [{'address_name': '서울 서초구 염곡동 180-11',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '1141520450',
#    'phone': '02-579-5060',
#    'place_name': '서초50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1141520450',
#    'road_address_name': '서울 서초구 염곡말길 9',
#    'x': '127.05118099910582',
#    'y': '37.46192017245296'},
#   {'address_name': '서울 노원구 상계동 181-14',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '1722920230',
#    'phone': '02-930-5060',
#    'place_name': '노원50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1722920230',
#    'road_address_name': '서울 노원구 노원로30길 73',
#    'x': '127.070719943939',
#    'y': '37.6561199808309'},
#   {'address_name': '서울 강서구 등촌동 685',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '1702046915',
#    'phone': '02-6295-5060',
#    'place_name': '강서50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1702046915',
#    'road_address_name': '서울 강서구 강서로56가길 166',
#    'x': '126.84247365588999',
#    'y': '37.566387671720676'},
#   {'address_name': '서울 강북구 미아동 3-183',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '2065480650',
#    'phone': '02-986-5060',
#    'place_name': '강북50플러스센터',
#    'place_url': 'http://place.map.kakao.com/2065480650',
#    'road_address_name': '서울 강북구 오현로9길 49',
#    'x': '127.03336910123039',
#    'y': '37.61871224316172'},
#   {'address_name': '서울 영등포구 여의도동 56-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '27437819',
#    'phone': '02-2635-5060',
#    'place_name': '영등포50플러스센터',
#    'place_url': 'http://place.map.kakao.com/27437819',
#    'road_address_name': '서울 영등포구 여의대방로 372',
#    'x': '126.930709050883',
#    'y': '37.5181500261646'},
#   {'address_name': '서울 강동구 천호동 287-29',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '1659599361',
#    'phone': '02-482-5060',
#    'place_name': '강동50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1659599361',
#    'road_address_name': '서울 강동구 올림픽로 752',
#    'x': '127.12712662441',
#    'y': '37.5482061648044'},
#   {'address_name': '서울 금천구 독산동 293-14',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '1674535238',
#    'phone': '02-892-5060',
#    'place_name': '금천50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1674535238',
#    'road_address_name': '서울 금천구 범안로17길 22',
#    'x': '126.894438157435',
#    'y': '37.4674865950964'},
#   {'address_name': '서울 성북구 보문동5가 35',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '1789998385',
#    'phone': '02-923-5060',
#    'place_name': '성북50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1789998385',
#    'road_address_name': '서울 성북구 지봉로24길 26',
#    'x': '127.019328297073',
#    'y': '37.5838623582194'},
#   {'address_name': '서울 성동구 행당동 377',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지단체',
#    'distance': '',
#    'id': '746788829',
#    'phone': '02-2292-5060',
#    'place_name': '성동50플러스센터',
#    'place_url': 'http://place.map.kakao.com/746788829',
#    'road_address_name': '서울 성동구 왕십리로 241',
#    'x': '127.04010502543',
#    'y': '37.5571543305045'},
#   {'address_name': '서울 서대문구 홍제동 294-46',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교육,학문 > 교육단체',
#    'distance': '',
#    'id': '92593639',
#    'phone': '02-394-5060',
#    'place_name': '서대문50플러스센터',
#    'place_url': 'http://place.map.kakao.com/92593639',
#    'road_address_name': '서울 서대문구 통일로 484',
#    'x': '126.942466681333',
#    'y': '37.5914290696028'},
#   {'address_name': '서울 관악구 봉천동 1589-13',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '1786647191',
#    'phone': '02-882-5060',
#    'place_name': '관악50플러스센터',
#    'place_url': 'http://place.map.kakao.com/1786647191',
#    'road_address_name': '서울 관악구 관악로5길 95',
#    'x': '126.95122798636316',
#    'y': '37.47716629220058'},
#   {'address_name': '서울 양천구 신월동 1078-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '2083717794',
#    'phone': '02-2607-5060',
#    'place_name': '양천50플러스센터',
#    'place_url': 'http://place.map.kakao.com/2083717794',
#    'road_address_name': '서울 양천구 남부순환로83길 53',
#    'x': '126.8450820620219',
#    'y': '37.51801559590384'},
#   {'address_name': '서울 동작구 노량진동 57-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '27387735',
#    'phone': '02-3482-5060',
#    'place_name': '동작50플러스센터',
#    'place_url': 'http://place.map.kakao.com/27387735',
#    'road_address_name': '서울 동작구 노량진로 140',
#    'x': '126.941685620361',
#    'y': '37.5127247055656'},
#   {'address_name': '대구 달서구 성당동 804-7',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교육,학문 > 교육단체 > 평생교육원,사회교육원',
#    'distance': '',
#    'id': '851215477',
#    'phone': '053-667-3215',
#    'place_name': '달서50플러스센터 달서평생학습관',
#    'place_url': 'http://place.map.kakao.com/851215477',
#    'road_address_name': '대구 달서구 성당로 17',
#    'x': '128.558176574311',
#    'y': '35.8391451457663'},
#   {'address_name': '광주 동구 학동 870-3',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '2093195869',
#    'phone': '062-228-5050',
#    'place_name': '광주광역시 빛고을50플러스센터',
#    'place_url': 'http://place.map.kakao.com/2093195869',
#    'road_address_name': '광주 동구 남문로 692',
#    'x': '126.928874965292',
#    'y': '35.1323865643232'}],
#  'meta': {'is_end': False,
#   'pageable_count': 20,
#   'same_name': {'keyword': '50플러스 센터', 'region': [], 'selected_region': ''},
#   'total_count': 20}}

# %%
convert_name('중장년일자리희망센터')
# Out:
# {'documents': [{'address_name': '경남 창원시 성산구 신월동 100-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '서비스,산업 > 전문대행 > 직업소개,인력파견',
#    'distance': '',
#    'id': '789752070',
#    'phone': '055-286-8317',
#    'place_name': '중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/789752070',
#    'road_address_name': '경남 창원시 성산구 중앙대로228번길 6',
#    'x': '128.688424900112',
#    'y': '35.2324334322995'},
#   {'address_name': '강원특별자치도 원주시 단구동 1516-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '서비스,산업 > 전문대행 > 직업소개,인력파견',
#    'distance': '',
#    'id': '1805036114',
#    'phone': '033-735-0971',
#    'place_name': '중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/1805036114',
#    'road_address_name': '강원특별자치도 원주시 남원로 528',
#    'x': '127.947024432529',
#    'y': '37.3311285241318'},
#   {'address_name': '부산 부산진구 양정동 353-12',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '13323356',
#    'phone': '051-647-0452',
#    'place_name': '부산경총 중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/13323356',
#    'road_address_name': '부산 부산진구 중앙대로 900',
#    'x': '129.06966999307',
#    'y': '35.1704794614987'},
#   {'address_name': '광주 광산구 월곡동 679-11',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '서비스,산업 > 전문대행 > 컨설팅',
#    'distance': '',
#    'id': '1953189169',
#    'phone': '',
#    'place_name': '광주경총 중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/1953189169',
#    'road_address_name': '광주 광산구 하남대로 154',
#    'x': '126.810394822161',
#    'y': '35.1796741863641'},
#   {'address_name': '부산 사상구 괘법동 554-9',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '21907050',
#    'phone': '',
#    'place_name': '중장년일자리희망센터 KARP부산지회',
#    'place_url': 'http://place.map.kakao.com/21907050',
#    'road_address_name': '부산 사상구 사상로181번길 17',
#    'x': '128.985365521195',
#    'y': '35.1605326735072'},
#   {'address_name': '대전 서구 탄방동 700',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '27437144',
#    'phone': '042-489-3820',
#    'place_name': '노사발전재단 충청지사 중장년내일센터',
#    'place_url': 'http://place.map.kakao.com/27437144',
#    'road_address_name': '대전 서구 둔산중로 8',
#    'x': '127.387287589523',
#    'y': '36.3473155828659'},
#   {'address_name': '충남 아산시 배방읍 공수리 1569',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '1809766603',
#    'phone': '041-559-5761',
#    'place_name': '충남북부상공회의소 중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/1809766603',
#    'road_address_name': '충남 아산시 배방읍 배방로 22',
#    'x': '127.05396229502553',
#    'y': '36.77484213929805'},
#   {'address_name': '강원특별자치도 원주시 단구동 1516-6',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '25161564',
#    'phone': '033-735-0971',
#    'place_name': '노사발전재단 강원중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/25161564',
#    'road_address_name': '강원특별자치도 원주시 남원로 528',
#    'x': '127.947129434811',
#    'y': '37.3311339905672'},
#   {'address_name': '전남 목포시 상동 1121-4',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교육,학문 > 직업전문교육',
#    'distance': '',
#    'id': '23611395',
#    'phone': '061-280-0571',
#    'place_name': '목포상공회의소 중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/23611395',
#    'road_address_name': '전남 목포시 평화로 5',
#    'x': '126.428124156826',
#    'y': '34.7976438472747'},
#   {'address_name': '전북특별자치도 전주시 완산구 효자동2가 1239-2',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '15176738',
#    'phone': '063-222-1840',
#    'place_name': '노사발전재단 전북중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/15176738',
#    'road_address_name': '전북특별자치도 전주시 완산구 홍산로 261',
#    'x': '127.105497845677',
#    'y': '35.817034240382'},
#   {'address_name': '울산 남구 삼산동 1538-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '1350791211',
#    'phone': '052-289-8975',
#    'place_name': '노사발전재단 울산중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/1350791211',
#    'road_address_name': '울산 남구 삼산중로 144',
#    'x': '129.33626550636535',
#    'y': '35.54608339891306'},
#   {'address_name': '경기 평택시 이충동 608',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '619588573',
#    'phone': '031-646-1046',
#    'place_name': '평택상공회의소 중장년일자리희망센터',
#    'place_url': 'http://place.map.kakao.com/619588573',
#    'road_address_name': '경기 평택시 경기대로 1194',
#    'x': '127.06039377254073',
#    'y': '37.05324776809236'},
#   {'address_name': '서울 마포구 공덕동 254-8',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '12025744',
#    'phone': '02-6021-1000',
#    'place_name': '노사발전재단',
#    'place_url': 'http://place.map.kakao.com/12025744',
#    'road_address_name': '서울 마포구 마포대로 130',
#    'x': '126.952948513367',
#    'y': '37.5459118145474'},
#   {'address_name': '충북 청주시 흥덕구 송정동 70-73',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회',
#    'distance': '',
#    'id': '726739498',
#    'phone': '043-221-1390',
#    'place_name': '충북경영자총협회',
#    'place_url': 'http://place.map.kakao.com/726739498',
#    'road_address_name': '충북 청주시 흥덕구 직지대로436번길 76',
#    'x': '127.44028153341324',
#    'y': '36.640572198971526'},
#   {'address_name': '인천 남동구 구월동 1128-10',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 공사,공단',
#    'distance': '',
#    'id': '12131566',
#    'phone': '1588-2089',
#    'place_name': '노사발전재단 차별없는일터지원단 경인사무소',
#    'place_url': 'http://place.map.kakao.com/12131566',
#    'road_address_name': '인천 남동구 미래로 7',
#    'x': '126.70397693863309',
#    'y': '37.450703324203126'}],
#  'meta': {'is_end': True,
#   'pageable_count': 15,
#   'same_name': {'keyword': '중장년일자리희망센터', 'region': [], 'selected_region': ''},
#   'total_count': 15}}

# %%
convert_name('노인일자리센터')
# Out:
# {'documents': [{'address_name': '전북특별자치도 전주시 완산구 중화산동2가 266-13',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '331946821',
#    'phone': '063-255-9113',
#    'place_name': '전북노인일자리센터',
#    'place_url': 'http://place.map.kakao.com/331946821',
#    'road_address_name': '전북특별자치도 전주시 완산구 백제대로 342',
#    'x': '127.12328479254643',
#    'y': '35.82371908463484'},
#   {'address_name': '경남 김해시 흥동 415-4',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 고용노동부',
#    'distance': '',
#    'id': '10197436',
#    'phone': '055-323-6588',
#    'place_name': '김해노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/10197436',
#    'road_address_name': '경남 김해시 흥동로 150',
#    'x': '128.864971336254',
#    'y': '35.2220226026637'},
#   {'address_name': '경북 구미시 도량동 741-4',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 고용노동부',
#    'distance': '',
#    'id': '17490188',
#    'phone': '054-443-7273',
#    'place_name': '구미 노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/17490188',
#    'road_address_name': '경북 구미시 문장로12안길 4',
#    'x': '128.333897804193',
#    'y': '36.1402253046229'},
#   {'address_name': '경남 양산시 북부동 481',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 고용노동부',
#    'distance': '',
#    'id': '1226133565',
#    'phone': '055-392-5651',
#    'place_name': '양산노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/1226133565',
#    'road_address_name': '경남 양산시 북안남2길 36',
#    'x': '129.037464260977',
#    'y': '35.3469956520365'},
#   {'address_name': '경기 고양시 일산서구 대화동 841-3',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '12453072',
#    'phone': '031-904-2611',
#    'place_name': '고양시 노인일자리종합센터',
#    'place_url': 'http://place.map.kakao.com/12453072',
#    'road_address_name': '경기 고양시 일산서구 대화로 142-20',
#    'x': '126.736556436644',
#    'y': '37.6707059520812'},
#   {'address_name': '대전 서구 둔산동 938',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '586846597',
#    'phone': '',
#    'place_name': '중부노인일자리통합지원센터',
#    'place_url': 'http://place.map.kakao.com/586846597',
#    'road_address_name': '대전 서구 청사로 152',
#    'x': '127.380677476742',
#    'y': '36.3595071842606'},
#   {'address_name': '경남 진주시 봉래동 216',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '10083044',
#    'phone': '055-744-6088',
#    'place_name': '진주노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/10083044',
#    'road_address_name': '경남 진주시 의곡길30번길 4',
#    'x': '128.082321134656',
#    'y': '35.199743795316'},
#   {'address_name': '경남 창원시 마산합포구 평화동 4-3',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 보건복지부',
#    'distance': '',
#    'id': '8673240',
#    'phone': '055-246-6588',
#    'place_name': '마산노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/8673240',
#    'road_address_name': '경남 창원시 마산합포구 문화북4길 15',
#    'x': '128.55879717023672',
#    'y': '35.18836804977364'},
#   {'address_name': '경남 창원시 성산구 중앙동 95-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '14646232',
#    'phone': '055-286-6588',
#    'place_name': '창원노인일자리창출지원센터',
#    'place_url': 'http://place.map.kakao.com/14646232',
#    'road_address_name': '경남 창원시 성산구 용지로 96',
#    'x': '128.678069431019',
#    'y': '35.224120435854'},
#   {'address_name': '경기 의왕시 청계동 824-2',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '151628510',
#    'phone': '',
#    'place_name': '의왕시노인일자리지원센터',
#    'place_url': 'http://place.map.kakao.com/151628510',
#    'road_address_name': '경기 의왕시 백운로 584',
#    'x': '126.998350227399',
#    'y': '37.3877351465648'},
#   {'address_name': '경기 수원시 장안구 파장동 184',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '574453729',
#    'phone': '031-222-6026',
#    'place_name': '경기도 노인일자리지원센터',
#    'place_url': 'http://place.map.kakao.com/574453729',
#    'road_address_name': '경기 수원시 장안구 경수대로 1150',
#    'x': '126.99347943229905',
#    'y': '37.31546796344028'},
#   {'address_name': '경남 함안군 칠원읍 구성리 799-3',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '848352685',
#    'phone': '',
#    'place_name': '칠원노인일자리센터',
#    'place_url': 'http://place.map.kakao.com/848352685',
#    'road_address_name': '경남 함안군 칠원읍 서남길 77',
#    'x': '128.520236141891',
#    'y': '35.3054021635138'},
#   {'address_name': '부산 중구 영주동 244-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '서비스,산업 > 전문대행 > 직업소개,인력파견',
#    'distance': '',
#    'id': '25974683',
#    'phone': '',
#    'place_name': '중구 노인일자리지원센터',
#    'place_url': 'http://place.map.kakao.com/25974683',
#    'road_address_name': '부산 중구 망양로383번안길 19',
#    'x': '129.029700354706',
#    'y': '35.109883686093'},
#   {'address_name': '강원특별자치도 홍천군 홍천읍 진리 20-10',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설 > 노인복지시설',
#    'distance': '',
#    'id': '935350521',
#    'phone': '033-432-8801',
#    'place_name': '홍천군노인일자리전담센터',
#    'place_url': 'http://place.map.kakao.com/935350521',
#    'road_address_name': '강원특별자치도 홍천군 홍천읍 너브내길 127',
#    'x': '127.89205658306615',
#    'y': '37.69208933098083'},
#   {'address_name': '전북특별자치도 부안군 부안읍 봉덕리 532',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 단체,협회 > 사회복지시설',
#    'distance': '',
#    'id': '88115146',
#    'phone': '',
#    'place_name': '노인일자리지원센터',
#    'place_url': 'http://place.map.kakao.com/88115146',
#    'road_address_name': '전북특별자치도 부안군 부안읍 매창로 165',
#    'x': '126.736784634767',
#    'y': '35.7190050364665'}],
#  'meta': {'is_end': False,
#   'pageable_count': 17,
#   'same_name': {'keyword': '노인일자리센터', 'region': [], 'selected_region': ''},
#   'total_count': 17}}

# %% [markdown]
# ## visualization

# %% [markdown]
# ### facility

# %%
facility
# Out:
#       MLSFC_NM      FCLTY_NM CTPRVN_NM SIGNGU_NM  \
# 0          복지관     1318상상발전소     서울특별시       중랑구
# 1          복지관       1318해피존     서울특별시       용산구
# 2          복지관   153재가장기요양기관     서울특별시       중랑구
# 3     노인정/노인회관     3단지아파트노인정     서울특별시       강서구
# 4          복지관  99팔팔재가노인복지센터     서울특별시       강서구
# ...        ...           ...       ...       ...
# 6791    노인복지시설      삼부아파트경로당     서울특별시       성동구
# 6792    노인복지시설   행당한신 제2 경로당     서울특별시       성동구
# 6793    노인복지시설     명륜2,4가경로당     서울특별시       종로구
# 6794    노인복지시설     종로5,6가경로당     서울특별시       종로구
# 6795    노인복지시설   두산4,5단지 경로당     서울특별시       중랑구
#
#                            RDNMADR_NM    FCLTY_LO   FCLTY_LA
# 0               서울특별시 중랑구 묵동 중랑역로 142  127.077072  37.606135
# 1              서울특별시 용산구 한강로3가 청파로 46  126.956555  37.531929
# 2          서울특별시 중랑구 면목동 사가정로46가길 3-5  127.083549  37.578477
# 3               서울특별시 강서구 가양동 허준로 139  126.856279  37.564612
# 4              서울특별시 강서구 화곡동 공항대로 426  126.854230  37.554832
# ...                               ...         ...        ...
# 6791              서울특별시 성동구 행당동 147번지         NaN        NaN
# 6792  서울특별시 성동구 행당동 201 201동 105,106호         NaN        NaN
# 6793           서울특별시 종로구 명륜4가 206-8번지         NaN        NaN
# 6794            서울특별시 종로구 효제동 173-2번지         NaN        NaN
# 6795             서울특별시 중랑구 면목동 1522번지         NaN        NaN
#
# [6796 rows x 7 columns]

# %%
order = facility['SIGNGU_NM'].value_counts().sort_values(ascending=False).index
order
# Out:
# Index(['강서구', '노원구', '강남구', '영등포구', '구로구', '양천구', '성북구', '송파구', '강동구', '마포구',
#        '은평구', '서초구', '성동구', '동작구', '도봉구', '관악구', '동대문구', '중랑구', '서대문구', '용산구',
#        '강북구', '광진구', '종로구', '금천구', '중구'],
#       dtype='object', name='SIGNGU_NM')

# %%
facility_count = facility['SIGNGU_NM'].value_counts().to_frame().reset_index()
facility_count.head()
# Out:
#   SIGNGU_NM  count
# 0       강서구    427
# 1       노원구    403
# 2       강남구    355
# 3      영등포구    345
# 4       구로구    341

# %%
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)
# 0  종로구    23.91    3.95
# 1   중구     9.96    1.65
# 2  용산구    21.87    3.61
# 3  성동구    16.82    2.78
# 4  광진구    17.06    2.82

# %%
merged_facility = pd.merge(left=facility_count, right=area, left_on='SIGNGU_NM', right_on='구별', how='left')
merged_facility.drop(columns='구별', inplace=True)
merged_facility.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)
# 0       강서구    427    41.45    6.85
# 1       노원구    403    35.44    5.86
# 2       강남구    355     39.5    6.53
# 3      영등포구    345    24.55    4.06
# 4       구로구    341    20.12    3.32

# %%
merged_facility['ratio'] = merged_facility['count'] / merged_facility['면적 (km²)']
merged_facility.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)      ratio
# 0       강서구    427    41.45    6.85  10.301568
# 1       노원구    403    35.44    5.86  11.371332
# 2       강남구    355     39.5    6.53   8.987342
# 3      영등포구    345    24.55    4.06  14.052953
# 4       구로구    341    20.12    3.32   16.94831

# %%
merged_facility.sort_values(by='ratio', ascending=False)['SIGNGU_NM'].values
# Out:
# array(['양천구', '구로구', '동대문구', '성동구', '동작구', '중구', '영등포구', '서대문구', '성북구',
#        '금천구', '중랑구', '마포구', '도봉구', '강동구', '노원구', '광진구', '강서구', '용산구',
#        '은평구', '송파구', '강남구', '강북구', '관악구', '종로구', '서초구'], dtype=object)

# %%
order = merged_facility.sort_values(by='ratio', ascending=False)['SIGNGU_NM'].values

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merged_facility, x='SIGNGU_NM', y='ratio', order=order)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # 소수점 두 자리까지만 표시
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("Facility Density in Seoul for Older Populations")
plt.show()

# %% [markdown]
# * 양천구 -> 구로구 -> 동대문구 -> 성동구 -> 동작구

# %% [markdown]
# * 서초구 -> 종로구 -> 관악구 -> 강북구 -> 강남구

# %% [markdown]
# ### Ageing index

# %%
old_point.head()
# Out:
#     구별     합계     남자     여자
# 0  종로구  267.8  237.3    298
# 1   중구  286.5  245.3  329.3
# 2  용산구  200.7  172.2    230
# 3  성동구  193.4  167.5  219.9
# 4  광진구  211.1  183.7  240.1

# %%
sorted_order = old_point.sort_values(by='합계', ascending=False)['구별']

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=old_point, x='구별', y='합계', order=sorted_order)
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.title("Ageing index")
plt.show()

# %% [markdown]
# ### Elderly dependency rate

# %%
old_pop.head()
# Out:
#     구별 유소년인구 생산가능인구  고령인구
# 0  종로구     7   74.1  18.9
# 1   중구   6.8   73.6  19.6
# 2  용산구   8.6   74.1  17.3
# 3  성동구   8.9   73.8  17.3
# 4  광진구   7.7   76.1  16.2

# %%
sorted_order = old_pop.sort_values(by='고령인구', ascending=False)['구별']

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=old_pop, x='구별', y='고령인구', order=sorted_order)
for p in ax.patches:
    ax.annotate(f'{float(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.title("Elderly dependency rate")
plt.show()

# %% [markdown]
# * 강북구 -> 도봉구 -> 중랑구 -> 구로구 -> 중구
# * 마포구 -> 강남구 -> 서초구 -> 광진구 -> 송파구
