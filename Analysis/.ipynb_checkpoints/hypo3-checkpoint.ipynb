# %% [markdown]
# # hypo3 - 노령화 지수가 높은 지역일수록, 노인의 교육시설이 많을 것이다

# %% [markdown]
# ## import

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from matplotlib import rc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import googlemaps
import seaborn as sns
import os
import re
import time

if os.name == 'nt':
    print("This is a Windows environment.")
    rc('font', family='Malgun Gothic') 

elif os.name == 'posix':
    print("This is a Mac or Linux environment.")
    rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# This is a Mac or Linux environment.

# %%
crawling = pd.read_csv('./data/job_support_old_pop.csv', index_col=0)
crawling.head()
# Out:
#                  FCLTY_NM SIGNGU_NM                     FCLTY_ROAD_NM_ADDR  \
# 0  강남고령자취업알선센터(강남노인종합복지관)       강남구     서울 강남구 삼성로 628 (삼성동, 강남구청 삼성로 별관)
# 1             강남구 일자리지원센터       강남구   서울 강남구 학동로 426 (삼성동, 강남구청) 강남구청 본관1층
# 2               강동50플러스센터       강동구      서울 강동구 올림픽로 752 (천호동, 강동50플러스센터)
# 3  강동고령자취업알선센터(강동노인종합복지관)       강동구   서울 강동구 동남로71길 32-5 (명일동, 강동노인종합복지관)
# 4               강동구 일자리센터       강동구  서울 강동구 성내로 25 (성내동, 강동구청) 본관 5층 일자리센터
#
#                                 LNM_ADDR   FCLTY_LA    FCLTY_LO
# 0     서울 강남구 삼성로 628 (삼성동, 강남구청 삼성로 별관)   37.516061  127.052123
# 1   서울 강남구 학동로 426 (삼성동, 강남구청) 강남구청 본관1층  37.517507  127.047375
# 2      서울 강동구 올림픽로 752 (천호동, 강동50플러스센터)   37.548206  127.127067
# 3   서울 강동구 동남로71길 32-5 (명일동, 강동노인종합복지관)   37.551781  127.153070
# 4  서울 강동구 성내로 25 (성내동, 강동구청) 본관 5층 일자리센터  37.530122  127.123748

# %% [markdown]
# ### job_support crawling

# %%
driver = webdriver.Chrome()
base_url = "https://goldenjob.or.kr/infor/support-organ.asp?tn=&keyfield=&keyword=&centerLocalArea_s=&p="

name_list = []
gu_list = []
addr_list = []

for page_number in range(1, 14):
    url = base_url+str(page_number)
    driver.get(url)
    results = driver.find_elements(By.CSS_SELECTOR, 'body > div.contents-wrap > section.contents.boardList_basic > div.inner.list_normal > table > tbody > tr')
    for result in results:
        name = result.text.split('\n')[0]
        name = re.sub(r'^\d+\s', '', name)
        gu = name.split(' ')[-1]
        addr = result.text.split('\n')[-1]
        
        name_list.append(name)
        gu_list.append(gu)
        addr_list.append(addr)
        
    time.sleep(2)
    
print(len(name_list), len(gu_list), len(addr_list))
print(name_list[:5], gu_list[:5], addr_list[:5])
driver.quit()
# Out:
# 182 182 182
# ['강남고령자취업알선센터(강남노인종합복지관) 강남', '강남구 일자리지원센터 강남', '강동50플러스센터 강동', '강동고령자취업알선센터(강동노인종합복지관) 강동', '강동구 일자리센터 강동'] ['강남', '강남', '강동', '강동', '강동'] ['서울 강남구 삼성로 628 (삼성동, 강남구청 삼성로 별관) ', '서울 강남구 학동로 426 (삼성동, 강남구청) 강남구청 본관1층', '서울 강동구 올림픽로 752 (천호동, 강동50플러스센터) ', '서울 강동구 동남로71길 32-5 (명일동, 강동노인종합복지관) ', '서울 강동구 성내로 25 (성내동, 강동구청) 본관 5층 일자리센터']

# %%
name_list = [name[:-3] for name in name_list]

# %%
gu_list = [f"{gu}구" if gu != '중구' else gu for gu in gu_list]

# %%
len(name_list), len(gu_list), len(addr_list)
# Out:
# (182, 182, 182)

# %%
# crawling = pd.DataFrame(
#     data={
#         'FCLTY_NM' : name_list,
#         'SIGNGU_NM' : gu_list,
#         'FCLTY_ROAD_NM_ADDR' : addr_list,
#         'LNM_ADDR' : addr_list,
#         'FCLTY_LA' : np.nan,
#         'FCLTY_LO' : np.nan
#     }
# )
# crawling.head()

# %%
# crawling.to_csv('./data/job_support_old_pop.csv', encoding='cp949')

# %% [markdown]
# ## edu

# %%
edu = pd.read_csv('./data/KC_ODSN_CNTEDU_FCLTY_LIST_2023.csv')
edu.head()
# Out:
#               ESNTL_ID LCLAS_NM     MLSFC_NM          FCLTY_NM  CTPRVN_CD  \
# 0  KCOEFPO23N000000001     문화시설  문화시설_교육_시니어  전남대학교용봉동캠퍼스평생교육원         29
# 1  KCOEFPO23N000000002     문화시설  문화시설_교육_시니어        고려대학교평생교육원         11
# 2  KCOEFPO23N000000003     문화시설  문화시설_교육_시니어      서울여자대학교평생교육원         11
# 3  KCOEFPO23N000000004     문화시설  문화시설_교육_시니어      광주가톨릭평생교육원본관         29
# 4  KCOEFPO23N000000005     문화시설  문화시설_교육_시니어        세종대학교평생교육원         11
#
#   CTPRVN_NM  SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# 0     광주광역시      29170        북구    2917010700          NaN  ...
# 1     서울특별시      11290       성북구    1129013500          NaN  ...
# 2     서울특별시      11350       노원구    1135010300          NaN  ...
# 3     광주광역시      29140        서구    2914011800          NaN  ...
# 4     서울특별시      11215       광진구    1121510900          NaN  ...
#
#               BULD_MANAGE_CD TEL_NO   ZIP_NO HMPG_URL   FCLTY_LA    FCLTY_LO  \
# 0  2917010700103000000024363    NaN  61186.0      NaN  35.179328  126.907701
# 1  1129012500100010002039525    NaN   2841.0      NaN  37.590228  127.035858
# 2  1135010300101260000014437    NaN   1797.0      NaN  37.627234  127.090297
# 3  2914011800109970001008995    NaN  61995.0      NaN  35.150379  126.868303
# 4  1121510900100980000018572    NaN   5006.0      NaN  37.553244  127.073381
#
#   ORIGIN_NM  ADIT_DC   UPDT_DT  REGIST_DT
# 0     공공데이터        -  20231231   20231231
# 1     공공데이터        -  20231231   20231231
# 2     공공데이터        -  20231231   20231231
# 3     공공데이터        -  20231231   20231231
# 4     공공데이터        -  20231231   20231231
#
# [5 rows x 26 columns]

# %%
edu = edu[edu['CTPRVN_NM'] == '서울특별시']
edu.reset_index(drop=True, inplace=True)
edu.head()
# Out:
#               ESNTL_ID LCLAS_NM     MLSFC_NM        FCLTY_NM  CTPRVN_CD  \
# 0  KCOEFPO23N000000002     문화시설  문화시설_교육_시니어      고려대학교평생교육원         11
# 1  KCOEFPO23N000000003     문화시설  문화시설_교육_시니어    서울여자대학교평생교육원         11
# 2  KCOEFPO23N000000005     문화시설  문화시설_교육_시니어      세종대학교평생교육원         11
# 3  KCOEFPO23N000000006     문화시설  문화시설_교육_시니어    이화여자대학교평생교육원         11
# 4  KCOEFPO23N000000017     문화시설  문화시설_교육_시니어  서울과학기술대학교평생교육원         11
#
#   CTPRVN_NM  SIGNGU_CD SIGNGU_NM  LEGALDONG_CD LEGALDONG_NM  ...  \
# 0     서울특별시      11290       성북구    1129013500          NaN  ...
# 1     서울특별시      11350       노원구    1135010300          NaN  ...
# 2     서울특별시      11215       광진구    1121510900          NaN  ...
# 3     서울특별시      11410      서대문구    1141011300          NaN  ...
# 4     서울특별시      11350       노원구    1135010300          NaN  ...
#
#               BULD_MANAGE_CD TEL_NO  ZIP_NO HMPG_URL   FCLTY_LA    FCLTY_LO  \
# 0  1129012500100010002039525    NaN  2841.0      NaN  37.590228  127.035858
# 1  1135010300101260000014437    NaN  1797.0      NaN  37.627234  127.090297
# 2  1121510900100980000018572    NaN  5006.0      NaN  37.553244  127.073381
# 3  1141011300100330000024353    NaN  3765.0      NaN  37.562082  126.943160
# 4  1135010300100780001000170    NaN  1811.0      NaN  37.630710  127.078560
#
#   ORIGIN_NM  ADIT_DC   UPDT_DT  REGIST_DT
# 0     공공데이터        -  20231231   20231231
# 1     공공데이터        -  20231231   20231231
# 2     공공데이터        -  20231231   20231231
# 3     공공데이터        -  20231231   20231231
# 4     공공데이터        -  20231231   20231231
#
# [5 rows x 26 columns]

# %%
edu.drop(columns=['LCLAS_NM', 'MLSFC_NM', 'ESNTL_ID', 'CTPRVN_NM', 'CTPRVN_CD', 'SIGNGU_CD', 'LEGALDONG_CD', 'ROAD_NM_CD' , 'TEL_NO', 'ZIP_NO',
                        'LEGALDONG_NM', 'ADDR_ENG_NM', 'ADSTRD_CD', 'BULD_NM', 'BULD_MANAGE_CD', 'HMPG_URL', 'ORIGIN_NM', 'ADIT_DC',
                        'UPDT_DT', 'REGIST_DT'], inplace=True)
edu.reset_index(drop=True, inplace=True)
edu.head()
# Out:
#          FCLTY_NM SIGNGU_NM         FCLTY_ROAD_NM_ADDR  \
# 0      고려대학교평생교육원       성북구  서울특별시 성북구 안암로 145 (안암동5가)
# 1    서울여자대학교평생교육원       노원구    서울특별시 노원구 화랑로 621 (공릉동)
# 2      세종대학교평생교육원       광진구    서울특별시 광진구 능동로 209 (군자동)
# 3    이화여자대학교평생교육원      서대문구   서울특별시 서대문구 성산로 508 (대신동)
# 4  서울과학기술대학교평생교육원       노원구    서울특별시 노원구 공릉로 232 (공릉동)
#
#                          LNM_ADDR   FCLTY_LA    FCLTY_LO
# 0  서울특별시 성북구 안암동5가 1-2 고려대학교안암캠퍼스  37.590228  127.035858
# 1       서울특별시 노원구 공릉동 126 서울여자대학교  37.627234  127.090297
# 2          서울특별시 광진구 군자동 98 세종대학교  37.553244  127.073381
# 3       서울특별시 서대문구 대신동 33 이화삼성교육관  37.562082  126.943160
# 4     서울특별시 노원구 공릉동 172 서울과학기술대학교  37.630710  127.078560

# %%
edu.shape
# Out:
# (195, 6)

# %%
crawling.shape
# Out:
# (182, 6)

# %% [markdown]
# ## old-point

# %%
# old_point = pd.read_excel('./data/자치구별+노령화지수(추계인구)_20240929181758.xlsx')
# old_point.head()

# %%
# old_point.drop(index=[0, 1], columns=["자치구별(1)"], inplace=True)
# old_point.columns = ['구별', '노령화지수_합계', '노령화지수_남자', '노령화지수_여자']
# old_point.reset_index(drop=True, inplace=True)
# old_point.head()

# %% [markdown]
# ### area

# %%
area = pd.read_excel('./data/행정구역(구별)_20241215143907.xlsx')
area.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)      2023   2023.1 2023.2 2023.3 2023.4 2023.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계     605.2      100    426    467  12926  96663
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    256   1568

# %%
area.drop(columns='자치구별(1)', index=[0,2], inplace=True)
area.columns = area.loc[1, :]
area.drop(index=1, inplace=True)
area.reset_index(drop=True, inplace=True)
area.head()
# Out:
# 1 자치구별(2) 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0     종로구    23.91    3.95  17  87  279  1475
# 1      중구     9.96    1.65  15  74  256  1568
# 2     용산구    21.87    3.61  16  36  357  2599
# 3     성동구    16.82    2.78  17  17  471  3645
# 4     광진구    17.06    2.82  15   7  370  3012

# %%
area.rename(columns={"자치구별(2)" : '구별'}, inplace=True)
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0  종로구    23.91    3.95  17  87  279  1475
# 1   중구     9.96    1.65  15  74  256  1568
# 2  용산구    21.87    3.61  16  36  357  2599
# 3  성동구    16.82    2.78  17  17  471  3645
# 4  광진구    17.06    2.82  15   7  370  3012

# %%
area = area[['구별', '면적 (km²)', '구성비 (%)']]

# %% [markdown]
# ### merge

# %%
concated_edu = pd.concat([edu, crawling])
concated_edu.shape
# Out:
# (377, 6)

# %%
edu_count = concated_edu['SIGNGU_NM'].value_counts().sort_values(ascending=False).to_frame()
edu_count.reset_index(inplace=True)
edu_count.head()
# Out:
#   SIGNGU_NM  count
# 0       마포구     26
# 1       강남구     26
# 2      영등포구     25
# 3       서초구     23
# 4       구로구     22

# %%
merged_edu = pd.merge(left=edu_count, right=area, left_on='SIGNGU_NM', right_on='구별', how='left')
merged_edu.drop(columns='구별', inplace=True)
merged_edu.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)
# 0       마포구     26    23.85    3.94
# 1       강남구     26     39.5    6.53
# 2      영등포구     25    24.55    4.06
# 3       서초구     23    46.97    7.76
# 4       구로구     22    20.12    3.32

# %%
merged_edu['ratio'] = merged_edu['count'] / merged_edu['면적 (km²)']
merged_edu.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)     ratio
# 0       마포구     26    23.85    3.94  1.090147
# 1       강남구     26     39.5    6.53  0.658228
# 2      영등포구     25    24.55    4.06   1.01833
# 3       서초구     23    46.97    7.76  0.489674
# 4       구로구     22    20.12    3.32  1.093439

# %%
order = merged_edu.sort_values(by='ratio', ascending=False)['SIGNGU_NM'].values

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merged_edu, x='SIGNGU_NM', y='ratio', order=order)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # 소수점 두 자리까지만 표시
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("Facility Density in Seoul for Older Populations")
plt.show()

# %%
# SIGNGU_NM의 카테고리별 개수를 계산하고 오름차순으로 정렬
order = concated_edu['SIGNGU_NM'].value_counts().sort_values(ascending=False).index

plt.figure(figsize=(18, 10))
ax = sns.countplot(data=concated_edu, x='SIGNGU_NM', order=order)

# 값 레이블 추가
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("교육시설")
plt.show()

# %% [markdown]
# ### folium visualization

# %%
import folium
import json

# %%
m = folium.Map(location=[37.5821, 127.0146], zoom_start=11)

with open('./data/seoul_municipalities_geo_simple.json', 'r', encoding='utf-8') as f:
    geojson_data = json.load(f)

folium.GeoJson(
    geojson_data,
    name="GeoJSON Data"
).add_to(m)

for i, r in crawling.iterrows():
    folium.Marker(
        location=[r['FCLTY_LA'], r['FCLTY_LO']],
        popup=f"<p>{r['FCLTY_NM']}</p>"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26b5d61b0747e85d96751b984e48131e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26b5d61b0747e85d96751b984e48131e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26b5d61b0747e85d96751b984e48131e = L.map(
#                 &quot;map_26b5d61b0747e85d96751b984e48131e&quot;,
#                 {
#                     center: [37.5821, 127.0146],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99f3f1bfa2e24add64d9659ec9d144eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_99f3f1bfa2e24add64d9659ec9d144eb.addTo(map_26b5d61b0747e85d96751b984e48131e);
#
#
#
#         function geo_json_12b1bfb14a63881b7ae6972a0d999398_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_12b1bfb14a63881b7ae6972a0d999398 = L.geoJson(null, {
#                 onEachFeature: geo_json_12b1bfb14a63881b7ae6972a0d999398_onEachFeature,
#
#         });
#
#         function geo_json_12b1bfb14a63881b7ae6972a0d999398_add (data) {
#             geo_json_12b1bfb14a63881b7ae6972a0d999398
#                 .addData(data);
#         }
#             geo_json_12b1bfb14a63881b7ae6972a0d999398_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37.49886565522751], [127.1634944215765, 37.497445406097484], [127.16199885180917, 37.49402577547199], [127.16216448592424, 37.491639601211624], [127.16040295326431, 37.4877818619403], [127.15892216655034, 37.486126922469445], [127.15393282790794, 37.48483891408459], [127.15147990997852, 37.47745324805034], [127.1515017465549, 37.475633269417585], [127.14857580353349, 37.47381386382568], [127.14415938171436

# %%
m.save('map.html')

# %% [markdown]
# ## 역의관계 살펴보기

# %%
# SIGNGU_NM의 카테고리별 개수를 계산하고 오름차순으로 정렬
order = concated_edu['SIGNGU_NM'].value_counts().sort_values(ascending=False).index

plt.figure(figsize=(18, 10))
ax = sns.countplot(data=concated_edu, x='SIGNGU_NM', order=order)

# 값 레이블 추가
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("교육시설")
plt.show()

# %% [markdown]
# * 강북구 => 9개, 도봉구 => 8개, 은평구 => 11개

# %%
merged_edu[(merged_edu['SIGNGU_NM'] == '강북구') | (merged_edu['SIGNGU_NM'] == '도봉구') | (merged_edu['SIGNGU_NM'] == '은평구')]
# Out:
#    SIGNGU_NM  count 면적 (km²) 구성비 (%)     ratio
# 18       은평구     11    29.71    4.91  0.370246
# 22       강북구      9     23.6     3.9  0.381356
# 24       도봉구      8    20.65    3.41  0.387409

# %%
merged_edu.sort_values(by='면적 (km²)', ascending=False)['SIGNGU_NM'].values
# Out:
# array(['서초구', '강서구', '강남구', '노원구', '송파구', '은평구', '관악구', '강동구', '성북구',
#        '영등포구', '종로구', '마포구', '강북구', '용산구', '도봉구', '구로구', '중랑구', '서대문구',
#        '양천구', '광진구', '성동구', '동작구', '동대문구', '금천구', '중구'], dtype=object)

# %%
# SIGNGU_NM의 카테고리별 개수를 계산하고 오름차순으로 정렬
order = merged_edu.sort_values(by='면적 (km²)', ascending=False)['SIGNGU_NM'].values

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merged_edu, x='SIGNGU_NM', y='면적 (km²)', order=order)

# 값 레이블 추가
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("구 면적")
plt.show()

# %%
merged_edu.sort_values(by='면적 (km²)', ascending=False)
# Out:
#    SIGNGU_NM  count 면적 (km²) 구성비 (%)     ratio
# 3        서초구     23    46.97    7.76  0.489674
# 11       강서구     14    41.45    6.85  0.337756
# 1        강남구     26     39.5    6.53  0.658228
# 5        노원구     21    35.44    5.86  0.592551
# 7        송파구     16    33.88     5.6  0.472255
# 18       은평구     11    29.71    4.91  0.370246
# 13       관악구     13    29.57    4.89  0.439635
# 15       강동구     13    24.59    4.06   0.52867
# 8        성북구     15    24.58    4.06  0.610252
# 2       영등포구     25    24.55    4.06   1.01833
# 6        종로구     19    23.91    3.95  0.794647
# 0        마포구     26    23.85    3.94  1.090147
# 22       강북구      9     23.6     3.9  0.381356
# 16       용산구     11    21.87    3.61  0.502972
# 24       도봉구      8    20.65    3.41  0.387409
# 4        구로구     22    20.12    3.32  1.093439
# 17       중랑구     11     18.5    3.06  0.594595
# 19      서대문구     10    17.63    2.91  0.567215
# 23       양천구      8    17.41    2.88  0.459506
# 20       광진구     10    17.06    2.82  0.586166
# 12       성동구     14    16.82    2.78  0.832342
# 21       동작구      9    16.36     2.7  0.550122
# 9       동대문구     15    14.22    2.35  1.054852
# 14       금천구     13    13.02    2.15  0.998464
# 10        중구     15     9.96    1.65  1.506024

# %%
concated_edu[concated_edu['SIGNGU_NM'] == '강북구']
# Out:
#                    FCLTY_NM SIGNGU_NM                  FCLTY_ROAD_NM_ADDR  \
# 87              이에듀케이션평생교육원       강북구             서울특별시 강북구 도봉로 325 (수유동)
# 142                글로벌평생교육원       강북구               서울특별시 강북구 덕릉로 99 (번동)
# 154                 한길평생교육원       강북구             서울특별시 강북구 도봉로 229 (미아동)
# 179               한교원격평생교육원       강북구              서울특별시 강북구 덕릉로 115 (번동)
# 8                 강북50플러스센터       강북구   서울 강북구 오현로9길 49 (미아동, 강북50플러스센터)
# 9    강북고령자취업알선센터(강북노인종합복지관)       강북구  서울 강북구 삼양로92길 40 (수유동, 강북노인종합복지관)
# 10             강북구 일자리플러스센터       강북구  서울 강북구 도봉로89길 13 (수유동, 강북구청) 본관 1층
# 11               강북여성인력개발센터       강북구       서울 강북구 덕릉로 108 (미아동, 현웅빌딩) 3층
# 47              대한노인회 강북구지회       강북구   서울 강북구 삼양로 280-1 (미아동, 강북노인회관) 3층
#
#                                LNM_ADDR   FCLTY_LA    FCLTY_LO
# 87            서울특별시 강북구 수유동 229-15 수성타워  37.637334  127.024365
# 142          서울특별시 강북구 번동 448-2 북한산드림캐슬  37.635028  127.024609
# 154                 서울특별시 강북구 미아동 203-5  37.629079  127.024801
# 179           서울특별시 강북구 번동 443-113 승진빌딩  37.635134  127.026645
# 8     서울 강북구 오현로9길 49 (미아동, 강북50플러스센터)         NaN         NaN
# 9    서울 강북구 삼양로92길 40 (수유동, 강북노인종합복지관)         NaN         NaN
# 10   서울 강북구 도봉로89길 13 (수유동, 강북구청) 본관 1층        NaN         NaN
# 11        서울 강북구 덕릉로 108 (미아동, 현웅빌딩) 3층        NaN         NaN
# 47    서울 강북구 삼양로 280-1 (미아동, 강북노인회관) 3층        NaN         NaN

# %%
concated_edu[concated_edu['SIGNGU_NM'] == '도봉구']
# Out:
#                    FCLTY_NM SIGNGU_NM  \
# 94               넥스트원격평생교육원       도봉구
# 155                 한일평생교육원       도봉구
# 54              대한노인회 도봉구지회       도봉구
# 72   도봉고령자취업알선센터(도봉노인종합복지관)       도봉구
# 73             도봉구 일자리플러스센터       도봉구
# 74                  도봉시니어클럽       도봉구
# 75            도봉여성센터-도봉새일센터       도봉구
# 116          서울시50플러스 북부캠퍼스       도봉구
#
#                           FCLTY_ROAD_NM_ADDR  \
# 94                서울특별시 도봉구 도봉로110나길 49 (창동)
# 155                  서울특별시 도봉구 도봉로 911 (도봉동)
# 54                    서울 도봉구 마들로 536 (창동) 4층
# 72    서울 도봉구 도당로2길 12-13 (쌍문동, 시립도봉노인종합복지관)
# 73          서울 도봉구 마들로 656 (방학동, 도봉구청) 본관 1층
# 74         서울 도봉구 도당로 118 (방학동, 거성학마을아파트) 3층
# 75   서울 도봉구 방학로12길 28 (방학동, 도봉여성센터, 보육정보센터)
# 116          서울 도봉구 마들로13길 84 (창동, 창동 아우르네)
#
#                                     LNM_ADDR   FCLTY_LA    FCLTY_LO
# 94                   서울특별시 도봉구 창동 659-4 삼우빌딩  37.648314  127.035444
# 155                     서울특별시 도봉구 도봉동 560-14  37.685746  127.045684
# 54                    서울 도봉구 마들로 536 (창동) 4층        NaN         NaN
# 72    서울 도봉구 도당로2길 12-13 (쌍문동, 시립도봉노인종합복지관)         NaN         NaN
# 73          서울 도봉구 마들로 656 (방학동, 도봉구청) 본관 1층        NaN         NaN
# 74         서울 도봉구 도당로 118 (방학동, 거성학마을아파트) 3층        NaN         NaN
# 75   서울 도봉구 방학로12길 28 (방학동, 도봉여성센터, 보육정보센터)         NaN         NaN
# 116          서울 도봉구 마들로13길 84 (창동, 창동 아우르네)         NaN         NaN

# %%
concated_edu[concated_edu['SIGNGU_NM'] == '은평구']
# Out:
#                    FCLTY_NM SIGNGU_NM                FCLTY_ROAD_NM_ADDR  \
# 41                한양건축평생교육원       은평구          서울특별시 은평구 서오릉로 110 (대조동)
# 91              한국직업능력평생교육원       은평구           서울특별시 은평구 통일로 719 (대조동)
# 104              중앙독립문평생교육원       은평구       서울특별시 은평구 통일로87길 19-1 (갈현동)
# 127               으뜸원격평생교육원       은평구           서울특별시 은평구 통일로 876 (불광동)
# 66              대한노인회 은평구지회       은평구        서울 은평구 백련산로 159-3 (응암동) 2층
# 113             서울시50+서부캠퍼스       은평구     서울 은평구 통일로62길 7 (녹번동, 서울기록원)
# 158  은평고령자취업알선센터(은평노인종합복지관)       은평구  서울 은평구 연서로 415 (진관동, 은평노인종합복지관)
# 159            은평구 일자리플러스센터       은평구  서울 은평구 은평로 195 (녹번동, 은평구청) 본관 2층
# 160                 은평시니어클럽       은평구            서울 은평구 증산로23길 7 (신사동)
# 161              은평어르신일자리센터       은평구          서울 은평구 증산로23길 7 (신사동) 4층
# 162       은평여성인력개발센터-은평새일센터       은평구              서울 은평구 녹번로 76 (녹번동)
#
#                              LNM_ADDR   FCLTY_LA    FCLTY_LO
# 41          서울특별시 은평구 대조동 172-56 삼두빌딩  37.609865  126.920136
# 91                서울특별시 은평구 대조동 14-13  37.609930  126.930148
# 104               서울특별시 은평구 갈현동 425-3  37.623351  126.917413
# 127              서울특별시 은평구 불광동 484-78  37.621176  126.920249
# 66         서울 은평구 백련산로 159-3 (응암동) 2층        NaN         NaN
# 113     서울 은평구 통일로62길 7 (녹번동, 서울기록원)         NaN         NaN
# 158  서울 은평구 연서로 415 (진관동, 은평노인종합복지관)         NaN         NaN
# 159  서울 은평구 은평로 195 (녹번동, 은평구청) 본관 2층        NaN         NaN
# 160            서울 은평구 증산로23길 7 (신사동)         NaN         NaN
# 161          서울 은평구 증산로23길 7 (신사동) 4층        NaN         NaN
# 162              서울 은평구 녹번로 76 (녹번동)         NaN         NaN

# %%
old_pop = pd.read_excel('./data/자치구별+연령계층별+인구구성비(추계인구)_20241108190613.xlsx')
old_pop.head()
# Out:
#    자치구별(1)   2023  2023.1 2023.2
# 0  자치구별(1)  유소년인구  생산가능인구   고령인구
# 1       합계    9.1    72.8   18.1
# 2      종로구      7    74.1   18.9
# 3       중구    6.8    73.6   19.6
# 4      용산구    8.6    74.1   17.3

# %%
old_pop.drop(index=[0, 1], inplace=True)
old_pop.columns = ['구별', '유소년인구', '생산가능인구', '고령인구']
old_pop.reset_index(drop=True, inplace=True)
old_pop.head()
# Out:
#     구별 유소년인구 생산가능인구  고령인구
# 0  종로구     7   74.1  18.9
# 1   중구   6.8   73.6  19.6
# 2  용산구   8.6   74.1  17.3
# 3  성동구   8.9   73.8  17.3
# 4  광진구   7.7   76.1  16.2

# %%
old_pop[(old_pop['구별'] == "은평구") | (old_pop['구별'] == "도봉구") | (old_pop['구별'] == "강북구")]
# Out:
#      구별 유소년인구 생산가능인구  고령인구
# 8   강북구   7.2   69.6  23.2
# 9   도봉구   8.1   69.3  22.6
# 11  은평구   8.9   71.2  19.9

# %%
old_pop.sort_values(by='고령인구', ascending=False)
# Out:
#       구별 유소년인구 생산가능인구  고령인구
# 8    강북구   7.2   69.6  23.2
# 9    도봉구   8.1   69.3  22.6
# 6    중랑구   8.1   71.9    20
# 11   은평구   8.9   71.2  19.9
# 16   구로구   8.8   71.4  19.8
# 1     중구   6.8   73.6  19.6
# 0    종로구     7   74.1  18.9
# 10   노원구   9.6   71.5  18.9
# 17   금천구   6.9   74.2  18.8
# 5   동대문구     8   73.2  18.8
# 19   동작구   8.2   73.6  18.2
# 7    성북구   9.3   72.6  18.1
# 12  서대문구   8.8   73.2    18
# 24   강동구  10.9   71.1    18
# 18  영등포구   8.4   73.8  17.8
# 15   강서구   9.2     73  17.7
# 3    성동구   8.9   73.8  17.3
# 2    용산구   8.6   74.1  17.3
# 20   관악구   5.8   76.9  17.3
# 14   양천구  11.2   71.6  17.2
# 23   송파구  11.2   72.4  16.4
# 4    광진구   7.7   76.1  16.2
# 21   서초구  12.4   71.4  16.2
# 22   강남구  11.4   72.5  16.2
# 13   마포구   9.1   75.5  15.4

# %% [markdown]
# ### 평생교육원 데이터만 확인해보기

# %%
edu_count2 = edu["SIGNGU_NM"].value_counts().to_frame().reset_index()

# %%
merged_edu2 = pd.merge(left=edu_count2, right=area, left_on='SIGNGU_NM', right_on='구별', how='left')
merged_edu2.drop(columns='구별', inplace=True)
merged_edu2.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)
# 0       강남구     19     39.5    6.53
# 1      영등포구     16    24.55    4.06
# 2       서초구     16    46.97    7.76
# 3       구로구     15    20.12    3.32
# 4       종로구     14    23.91    3.95

# %%
merged_edu2['ratio'] = merged_edu2['count'] / merged_edu2['면적 (km²)']
merged_edu2.head()
# Out:
#   SIGNGU_NM  count 면적 (km²) 구성비 (%)     ratio
# 0       강남구     19     39.5    6.53  0.481013
# 1      영등포구     16    24.55    4.06  0.651731
# 2       서초구     16    46.97    7.76  0.340643
# 3       구로구     15    20.12    3.32  0.745527
# 4       종로구     14    23.91    3.95  0.585529

# %%
order = merged_edu2.sort_values(by='ratio', ascending=False)['SIGNGU_NM'].values

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merged_edu2, x='SIGNGU_NM', y='ratio', order=order)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # 소수점 두 자리까지만 표시
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("Facility Density in Seoul for Older Populations (Life Education)")
plt.show()

# %%
merged_edu2
# Out:
#    SIGNGU_NM  count 면적 (km²) 구성비 (%)     ratio
# 0        강남구     19     39.5    6.53  0.481013
# 1       영등포구     16    24.55    4.06  0.651731
# 2        서초구     16    46.97    7.76  0.340643
# 3        구로구     15    20.12    3.32  0.745527
# 4        종로구     14    23.91    3.95  0.585529
# 5        마포구     10    23.85    3.94  0.419287
# 6       동대문구      9    14.22    2.35  0.632911
# 7        성북구      8    24.58    4.06  0.325468
# 8        관악구      8    29.57    4.89  0.270544
# 9        송파구      8    33.88     5.6  0.236128
# 10       성동구      8    16.82    2.78  0.475624
# 11       노원구      8    35.44    5.86  0.225734
# 12       중랑구      7     18.5    3.06  0.378378
# 13       금천구      6    13.02    2.15  0.460829
# 14        중구      6     9.96    1.65   0.60241
# 15       강서구      5    41.45    6.85  0.120627
# 16       강동구      5    24.59    4.06  0.203335
# 17       용산구      4    21.87    3.61  0.182899
# 18       은평구      4    29.71    4.91  0.134635
# 19      서대문구      4    17.63    2.91  0.226886
# 20       광진구      4    17.06    2.82  0.234467
# 21       강북구      4     23.6     3.9  0.169492
# 22       동작구      3    16.36     2.7  0.183374
# 23       양천구      2    17.41    2.88  0.114877
# 24       도봉구      2    20.65    3.41  0.096852

# %%
edu
# Out:
#            FCLTY_NM SIGNGU_NM           FCLTY_ROAD_NM_ADDR  \
# 0        고려대학교평생교육원       성북구    서울특별시 성북구 안암로 145 (안암동5가)
# 1      서울여자대학교평생교육원       노원구      서울특별시 노원구 화랑로 621 (공릉동)
# 2        세종대학교평생교육원       광진구      서울특별시 광진구 능동로 209 (군자동)
# 3      이화여자대학교평생교육원      서대문구     서울특별시 서대문구 성산로 508 (대신동)
# 4    서울과학기술대학교평생교육원       노원구      서울특별시 노원구 공릉로 232 (공릉동)
# ..              ...       ...                          ...
# 190         위너평생교육원       송파구     서울특별시 송파구 법원로11길 7 (문정동)
# 191       송파CS평생교육원       송파구    서울특별시 송파구 백제고분로 420 (송파동)
# 192   서울메디필라테스평생교육원      영등포구  서울특별시 영등포구 여의대방로 375 (여의도동)
# 193   올에듀평생교육원소속멘토팀       구로구   서울특별시 구로구 디지털로33길 28 (구로동)
# 194     스마일스토리평생교육원       강서구   서울특별시 강서구 방화대로37길 49 (방화동)
#
#                               LNM_ADDR   FCLTY_LA    FCLTY_LO
# 0       서울특별시 성북구 안암동5가 1-2 고려대학교안암캠퍼스  37.590228  127.035858
# 1            서울특별시 노원구 공릉동 126 서울여자대학교  37.627234  127.090297
# 2               서울특별시 광진구 군자동 98 세종대학교  37.553244  127.073381
# 3            서울특별시 서대문구 대신동 33 이화삼성교육관  37.562082  126.943160
# 4          서울특별시 노원구 공릉동 172 서울과학기술대학교  37.630710  127.078560
# ..                                 ...        ...         ...
# 190  서울특별시 송파구 문정동 644-2 문정현대지식산업센터1-2  37.485349  127.119218
# 191                서울특별시 송파구 송파동 134-1  37.508347  127.111319
# 192       서울특별시 영등포구 여의도동 44-37 아일렉스타워  37.518898  126.930776
# 193      서울특별시 구로구 구로동 170-5 우림이비지센터1차  37.486982  126.895315
# 194              서울특별시 강서구 방화동 249-310  37.569837  126.813647
#
# [195 rows x 6 columns]

# %%
# SIGNGU_NM의 카테고리별 개수를 계산하고 오름차순으로 정렬
order = edu['SIGNGU_NM'].value_counts().sort_values(ascending=False).index

plt.figure(figsize=(18, 10))
ax = sns.countplot(data=edu, x='SIGNGU_NM', order=order)

# 값 레이블 추가
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title("교육시설")
plt.show()
