# %% [markdown]
# # hypo1 - 노령 인구 대비 CCTV 설치 대수 비율이 높을 수록, 노령 대상 범죄율은 낮을 것이다

# %% [markdown]
# ## import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import googlemaps
import seaborn as sns
from matplotlib import rc
import os
if os.name == 'nt':
    print("This is a Windows environment.")
    rc('font', family='Malgun Gothic')
elif os.name == 'posix':
    print("This is a Mac or Linux environment.")
    rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# This is a Mac or Linux environment.

# %%
cctv = pd.read_excel('./data/서울시 자치구 (연도별) CCTV 설치현황_240630.xlsx')
cctv.head()
# Out:
#     순번   구분     총 계  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  \
# 0  NaN    계  102380               11692   8225  10865  10652  12854  11838
# 1  1.0  종로구    2290                 230    100    140    140     66    233
# 2  2.0  중 구    3021                 376    220    366    381    155    357
# 3  3.0  용산구    3300                 106    295    491    147    335    473
# 4  4.0  성동구    4514                 542    278    939    457    640    483
#
#    2021년  2022년  2023년  2024년\n6.30.
# 0   9558   9218  13919          3559
# 1     85    219    919           158
# 2    414    137    135           480
# 3    486    413    492            62
# 4    366    233    471           105

# %%
crime = pd.read_csv("./data/경찰청 서울특별시경찰청_경찰서별 살인 및 폭력 죄종 피해자 성별 및 연령대별 현황_20231231.csv", encoding="cp949")
crime.head()
# Out:
#       구분       연령  피해자 수
# 0  중부 살인   남자6세이하      0
# 1  중부 살인  남자12세이하      0
# 2  중부 살인  남자15세이하      0
# 3  중부 살인  남자20세이하      0
# 4  중부 살인  남자30세이하      1

# %%
area = pd.read_excel('./data/행정구역(구별)_20241215143907.xlsx')
area.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)      2023   2023.1 2023.2 2023.3 2023.4 2023.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계     605.2      100    426    467  12926  96663
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    256   1568

# %% [markdown]
# ## data preprocessing

# %% [markdown]
# ### crime

# %%
crime.head()
# Out:
#       구분       연령  피해자 수
# 0  중부 살인   남자6세이하      0
# 1  중부 살인  남자12세이하      0
# 2  중부 살인  남자15세이하      0
# 3  중부 살인  남자20세이하      0
# 4  중부 살인  남자30세이하      1

# %%
drop_idx = crime[(crime['연령'].str.contains('이하')) | (crime['연령'].str.contains('미상'))].index
crime.drop(index=drop_idx, inplace=True)
crime
# Out:
#          구분       연령  피해자 수
# 8     중부 살인  남자60세이상      0
# 18    중부 살인  여자60세이상      1
# 28    중부 폭력  남자60세초과    139
# 38    중부 폭력  여자60세초과     53
# 48    종로 살인  남자60세초과      2
# ...     ...      ...    ...
# 1198  도봉 폭력  여자60세초과     64
# 1208  수서 살인  남자60세초과      0
# 1218  수서 살인  여자60세초과      2
# 1228  수서 폭력  남자60세초과    138
# 1238  수서 폭력  여자60세초과     63
#
# [124 rows x 3 columns]

# %%
station_list = []
crime_sort_list = []
for idx, row in crime.iterrows():
    station = row['구분'].split()[0]
    station_list.append(station)
    crime_sort = row['구분'].split()[1]
    crime_sort_list.append(crime_sort)

crime_sort_list[:5], station_list[:5]
# Out:
# (['살인', '살인', '폭력', '폭력', '살인'], ['중부', '중부', '중부', '중부', '종로'])

# %%
crime['구분'] = station_list
crime['죄종'] = crime_sort_list

crime.head()
# Out:
#     구분       연령  피해자 수  죄종
# 8   중부  남자60세이상      0  살인
# 18  중부  여자60세이상      1  살인
# 28  중부  남자60세초과    139  폭력
# 38  중부  여자60세초과     53  폭력
# 48  종로  남자60세초과      2  살인

# %%
crime_station = crime.groupby(['구분', '죄종'])["피해자 수"].sum().to_frame().reset_index()
crime_station.head()
# Out:
#    구분  죄종  피해자 수
# 0  강남  살인      1
# 1  강남  폭력    181
# 2  강동  살인      0
# 3  강동  폭력    262
# 4  강북  살인      5

# %%
crime_station = crime_station.pivot(index=['구분'], columns=['죄종'], values='피해자 수').reset_index()
crime_station.head()
# Out:
# 죄종  구분  살인   폭력
# 0   강남   1  181
# 1   강동   0  262
# 2   강북   5  240
# 3   강서   0  350
# 4   관악   3  383

# %%
crime_station['crime_sum'] = crime_station['살인'] + crime_station['폭력']

# %%
crime_station.head()
# Out:
# 죄종  구분  살인   폭력  crime_sum
# 0   강남   1  181        182
# 1   강동   0  262        262
# 2   강북   5  240        245
# 3   강서   0  350        350
# 4   관악   3  383        386

# %% [markdown]
# #### google maps api key

# %% [markdown]
# * AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI

# %%
gmaps_key = "AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI"

# %%
gmaps = googlemaps.Client(key=gmaps_key)

# %%
tmp = gmaps.geocode("서울영등포경찰서", language='ko')
tmp
# Out:
# [{'address_components': [{'long_name': '608',
#     'short_name': '608',
#     'types': ['premise']},
#    {'long_name': '국회대로',
#     'short_name': '국회대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-043',
#     'short_name': '150-043',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'geometry': {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5273930802915,
#      'lng': 126.9021580802915},
#     'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ1TimJLaffDURptXOs0Tj6sY',
#   'plus_code': {'compound_code': 'GWG2+C8 대한민국 서울특별시',
#    'global_code': '8Q98GWG2+C8'},
#   'types': ['establishment', 'point_of_interest', 'police']}]

# %%
tmp[0].get('geometry')
# Out:
# {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 37.5273930802915, 'lng': 126.9021580802915},
#   'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}}

# %%
tmp[0].get('geometry')['location']['lat']
# Out:
# 37.5260441

# %%
tmp[0].get('geometry')['location']['lng']
# Out:
# 126.9008091

# %%
tmp[0].get('formatted_address')
# Out:
# '대한민국 서울특별시 영등포구 국회대로 608'

# %%
tmp[0].get('formatted_address').split()[2]
# Out:
# '영등포구'

# %%
crime_station['구분'].head()
# Out:
# 0    강남
# 1    강동
# 2    강북
# 3    강서
# 4    관악
# Name: 구분, dtype: object

# %%
tmp_gu = []
lat_list = []
lng_list = []

for gubun in crime_station['구분']:
    station_name = "서울" + gubun + "경찰서"
    tmp = gmaps.geocode(station_name, language='ko')

    gu = tmp[0].get('formatted_address').split()[2]
    lat = tmp[0].get('geometry')['location']['lat']
    lng = tmp[0].get('geometry')['location']['lng']

    tmp_gu.append(gu)
    lat_list.append(lat)
    lng_list.append(lng)

# %%
tmp_gu[:5], lat_list[:5], lng_list[:5]
# Out:
# (['강남구', '강동구', '강북구', '강서구', '관악구'],
#  [37.5094352, 37.528511, 37.63719740000001, 37.5513622, 37.4743945],
#  [127.0669578, 127.1268224, 127.0273048, 126.8502799, 126.9513489])

# %%
crime_station['구별'] = tmp_gu
crime_station['lat'] = lat_list
crime_station['lng'] = lng_list
crime_station.head()
# Out:
# 죄종  구분  살인   폭력  crime_sum   구별        lat         lng
# 0   강남   1  181        182  강남구  37.509435  127.066958
# 1   강동   0  262        262  강동구  37.528511  127.126822
# 2   강북   5  240        245  강북구  37.637197  127.027305
# 3   강서   0  350        350  강서구  37.551362  126.850280
# 4   관악   3  383        386  관악구  37.474395  126.951349

# %%
m = folium.Map(location=[37.5502, 126.982], zoom_start=12)

for idx,row in crime_station.iterrows():
    lat = row['lat']
    lng = row['lng']
    name = row['구분'] + ' 경찰서'

    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(
            color='blue',
            icon_color='white'
        ),
        popup=name
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_889dca41b016a9802edd686638f37e32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_889dca41b016a9802edd686638f37e32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_889dca41b016a9802edd686638f37e32 = L.map(
#                 &quot;map_889dca41b016a9802edd686638f37e32&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0010d0b41807ec0e5dd0996ac7ad7630 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0010d0b41807ec0e5dd0996ac7ad7630.addTo(map_889dca41b016a9802edd686638f37e32);
#
#
#             var marker_98506b0128e8f829279d03a21c3fd276 = L.marker(
#                 [37.5094352, 127.0669578],
#                 {}
#             ).addTo(map_889dca41b016a9802edd686638f37e32);
#
#
#             var icon_7a0d34157cc33aed2ad68ecb86060d50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98506b0128e8f829279d03a21c3fd276.setIcon(icon_7a0d34157cc33aed2ad68ecb86060d50);
#
#
#         var popup_d44b7eac55519f7c9456423cac706bb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_586c6b506f61f084cc74ed15d6148767 = $(`&lt;div id=&quot;html_586c6b506f61f084cc74ed15d6148767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남 경찰서&lt;/div&gt;`)[0];
#                 popup_d44b7eac55519f7c9456423cac706bb6.setContent(html_586c6b506f61f084cc74ed15d6148767);
#
#
#
#         marker_98506b0128e8f829279d03a21c3fd276.bindPopup(popup_d44b7eac55519f7c9456423cac706bb6)
#         ;
#
#
#
#
#             var marker_4e21019b17dc3b9235f1ef44f20f918c = L.marker(
#                 [37.528511, 127.1268224],
#                 {}
#             ).addTo(map_889dca41b016a9802edd686638f37e32);
#
#
#             var icon_77a631e905f8d5c70dedf9a27507522d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4e21019b17dc3b9235f1ef44f20f918c.setIcon(icon_77a631e905f8d5c70dedf9a27507522d);
#
#
#         var popup_b5d43773a8313925595e00375ad09b50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed8de50fc63503ac3865947a461bfe61 = $(`&lt;div id=&quot;html_ed8de50fc63503ac3865947a461bfe61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동 경찰서&lt;/div&gt;`)[0];
#                 popup_b5d43773a8313925595e00375ad09b50.setContent(html_ed8de50fc63503ac3865947a461bfe61);
#
#
#
#         marker_4e21019b17dc3b9235f1ef44f20f918c.bindPopup(popup_b5d43773a8313925595e00375ad09b50)
#         ;
#
#
#
#
#             var marker_c96c29f9bed50d6e114d6acf0792bbb5 = L.marker(
#                 [37.63719740000001, 127.0273048],
#                 {}
#             ).addTo(map_889dca41b016a9802edd686638f37e32);
#
#
#             var icon_99eff209a7a56baef11f086245fcdeb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c96c29f9bed50d6e114d6acf0792bbb5.setIcon(icon_99eff209a7a56baef11f086245fcdeb5);
#
#
#         var popup_3a24f4435539bbccb0922122c752af2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a04a2ffd523e64bdfca0b307500b414 = $(`&lt;div id=&quot;html_5a04a2ffd523e64bdfca0b307500b414&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북 경찰서&lt;/div&gt;`)[0];
#                 popup_3a24f4435539bbccb0922122c752af2d.setContent(html_5a04a2ffd523e64bdfca0b307500b414);
#
#
#
#         marker_c96c29f9bed50d6e114d6acf0792bbb5.bindPopup(popup_3a24f4435539bbccb0922122c752af2d)
#         ;
#
#
#
#
#             var marker_07159932f564e27975e448510ed34259 = L.marker(
#                 [37.5513622, 126.8502799],
#                 {}
#             ).addTo(map_889dca41b016a9802edd686638f37e32);
#
#
#             var icon_5a3ef62b4493e11f1e97bec0ccefc57d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;marke

# %% [markdown]
# * 구별 데이터가 중복되는 것을 확인, 합치는 것이 필요

# %%
crime_station[crime_station['구별'] == '강남구']
# Out:
# 죄종  구분  살인   폭력  crime_sum   구별        lat         lng
# 0   강남   1  181        182  강남구  37.509435  127.066958
# 21  수서   2  201        203  강남구  37.493490  127.077212

# %%
crime_station.drop(columns=['구분', 'lat', 'lng'], inplace=True)

# %%
crime_station = crime_station.groupby('구별').sum().reset_index()
crime_station.head()
# Out:
# 죄종   구별  살인   폭력  crime_sum
# 0   강남구   3  382        385
# 1   강동구   0  262        262
# 2   강북구   5  240        245
# 3   강서구   0  350        350
# 4   관악구   3  383        386

# %% [markdown]
# ### cctv

# %%
cctv.drop(index=[0], columns=["순번", "총 계", "2024년\n6.30."], inplace=True)
cctv.reset_index(drop=True, inplace=True)
cctv.head()
# Out:
#     구분  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구                 230    100    140    140     66    233     85    219
# 1  중 구                 376    220    366    381    155    357    414    137
# 2  용산구                 106    295    491    147    335    473    486    413
# 3  성동구                 542    278    939    457    640    483    366    233
# 4  광진구                 403     42    666    460    712    191    740    273
#
#    2023년
# 0    919
# 1    135
# 2    492
# 3    471
# 4    340

# %%
cctv.columns[1:]
# Out:
# Index(['2016년 이전 설치된 CCTV ', '2016년', '2017년', '2018년', '2019년', '2020년',
#        '2021년', '2022년', '2023년'],
#       dtype='object')

# %%
cctv['CCTV_sum'] = cctv['2016년 이전 설치된 CCTV '] + cctv['2016년'] + cctv['2017년'] + cctv['2018년'] + cctv['2019년'] + cctv['2020년'] + cctv['2021년'] + cctv["2022년"] + cctv['2023년']
cctv.head()
# Out:
#     구분  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구                 230    100    140    140     66    233     85    219
# 1  중 구                 376    220    366    381    155    357    414    137
# 2  용산구                 106    295    491    147    335    473    486    413
# 3  성동구                 542    278    939    457    640    483    366    233
# 4  광진구                 403     42    666    460    712    191    740    273
#
#    2023년  CCTV_sum
# 0    919      2132
# 1    135      2541
# 2    492      3238
# 3    471      4409
# 4    340      3827

# %%
cctv.rename(columns={"구분" : "구별"}, inplace=True)
cctv = cctv[['구별', 'CCTV_sum']]
cctv.head()
# Out:
#     구별  CCTV_sum
# 0  종로구      2132
# 1  중 구      2541
# 2  용산구      3238
# 3  성동구      4409
# 4  광진구      3827

# %% [markdown]
# ### area

# %%
area.head()
# Out:
#    자치구별(1)  자치구별(2)      2023   2023.1 2023.2 2023.3 2023.4 2023.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계     605.2      100    426    467  12926  96663
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    256   1568

# %%
area.drop(columns='자치구별(1)', index=[0,2], inplace=True)

# %%
area.head()
# Out:
#    자치구별(2)      2023   2023.1 2023.2 2023.3 2023.4 2023.5
# 1  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 3      종로구     23.91     3.95     17     87    279   1475
# 4       중구      9.96     1.65     15     74    256   1568
# 5      용산구     21.87     3.61     16     36    357   2599
# 6      성동구     16.82     2.78     17     17    471   3645

# %%
area.columns = area.loc[1, :]

# %%
area.drop(index=1, inplace=True)
area.reset_index(drop=True, inplace=True)
area.head()
# Out:
# 1 자치구별(2) 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0     종로구    23.91    3.95  17  87  279  1475
# 1      중구     9.96    1.65  15  74  256  1568
# 2     용산구    21.87    3.61  16  36  357  2599
# 3     성동구    16.82    2.78  17  17  471  3645
# 4     광진구    17.06    2.82  15   7  370  3012

# %%
area.rename(columns={"자치구별(2)" : '구별'}, inplace=True)
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0  종로구    23.91    3.95  17  87  279  1475
# 1   중구     9.96    1.65  15  74  256  1568
# 2  용산구    21.87    3.61  16  36  357  2599
# 3  성동구    16.82    2.78  17  17  471  3645
# 4  광진구    17.06    2.82  15   7  370  3012

# %%
area = area[['구별', '면적 (km²)', '구성비 (%)']]
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)
# 0  종로구    23.91    3.95
# 1   중구     9.96    1.65
# 2  용산구    21.87    3.61
# 3  성동구    16.82    2.78
# 4  광진구    17.06    2.82

# %% [markdown]
# ### population

# %%
pop = pd.read_excel('./data/자치구별+고령인구(추계인구)_20241019165325.xlsx')
pop.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)     2023  2023.1  2023.2
# 0  자치구별(1)  자치구별(2)     고령인구    고령인구    고령인구
# 1  자치구별(1)  자치구별(2)       소계      남자      여자
# 2       합계       소계  1691853  749118  942735
# 3      NaN      종로구    27187   11986   15201
# 4      NaN       중구    24374   10637   13737

# %%
pop.drop(index=[0, 1, 2], columns=['자치구별(1)'], inplace=True)
pop.columns = ["구별", "노령인구_전체", "노령인구_남자", "노령인구_여자"]
pop.reset_index(drop=True, inplace=True)

# %%
pop.head()
# Out:
#     구별 노령인구_전체 노령인구_남자 노령인구_여자
# 0  종로구   27187   11986   15201
# 1   중구   24374   10637   13737
# 2  용산구   37740   16395   21345
# 3  성동구   47907   21034   26873
# 4  광진구   55697   24952   30745

# %% [markdown]
# ### old-point

# %%
# old_point = pd.read_excel('./data/자치구별+노령화지수(추계인구)_20240929181758.xlsx')
# old_point.head()

# %%
# old_point.drop(index=[0, 1], columns=["자치구별(1)"], inplace=True)
# old_point.columns = ['구별', '노령화지수_합계', '노령화지수_남자', '노령화지수_여자']
# old_point.reset_index(drop=True, inplace=True)
# old_point.head()

# %% [markdown]
# ### concat

# %%
cctv.head()
# Out:
#     구별  CCTV_sum
# 0  종로구      2132
# 1  중 구      2541
# 2  용산구      3238
# 3  성동구      4409
# 4  광진구      3827

# %%
crime_station.head()
# Out:
# 죄종   구별  살인   폭력  crime_sum
# 0   강남구   3  382        385
# 1   강동구   0  262        262
# 2   강북구   5  240        245
# 3   강서구   0  350        350
# 4   관악구   3  383        386

# %%
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)
# 0  종로구    23.91    3.95
# 1   중구     9.96    1.65
# 2  용산구    21.87    3.61
# 3  성동구    16.82    2.78
# 4  광진구    17.06    2.82

# %%
pop.head()
# Out:
#     구별 노령인구_전체 노령인구_남자 노령인구_여자
# 0  종로구   27187   11986   15201
# 1   중구   24374   10637   13737
# 2  용산구   37740   16395   21345
# 3  성동구   47907   21034   26873
# 4  광진구   55697   24952   30745

# %%
# old_point.head()

# %%
merge_crime = pd.merge(crime_station, cctv, left_on='구별', right_on='구별', how='inner')
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum
# 0  강남구   3  382        385      7721
# 1  강동구   0  262        262      3549
# 2  강북구   5  240        245      3531
# 3  강서구   0  350        350      3612
# 4  관악구   3  383        386      5549

# %%
merge_crime = pd.merge(merge_crime, area, on='구별')
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum 면적 (km²) 구성비 (%)
# 0  강남구   3  382        385      7721     39.5    6.53
# 1  강동구   0  262        262      3549    24.59    4.06
# 2  강북구   5  240        245      3531     23.6     3.9
# 3  강서구   0  350        350      3612    41.45    6.85
# 4  관악구   3  383        386      5549    29.57    4.89

# %%
merge_crime = pd.merge(merge_crime, pop, on='구별')
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum 면적 (km²) 구성비 (%) 노령인구_전체 노령인구_남자 노령인구_여자
# 0  강남구   3  382        385      7721     39.5    6.53   81561   36926   44635
# 1  강동구   0  262        262      3549    24.59    4.06   80131   36613   43518
# 2  강북구   5  240        245      3531     23.6     3.9   65980   28373   37607
# 3  강서구   0  350        350      3612    41.45    6.85   98380   43366   55014
# 4  관악구   3  383        386      5549    29.57    4.89   84596   37422   47174

# %%
# merge_crime = pd.merge(merge_crime, old_point, on='구별')
# merge_crime.head()

# %%
merge_crime['면적 (km²)'] = merge_crime['면적 (km²)'].astype(float) 
merge_crime['구성비 (%)'] = merge_crime['구성비 (%)'].astype(float)
merge_crime['노령인구_전체'] = merge_crime['노령인구_전체'].astype(int)
merge_crime['노령인구_남자'] = merge_crime['노령인구_남자'].astype(int)
merge_crime['노령인구_여지'] = merge_crime['노령인구_여자'].astype(int)
# merge_crime['노령화지수_합계'] = merge_crime['노령화지수_합계'].astype(float)
# merge_crime['노령화지수_남자'] = merge_crime['노령화지수_남자'].astype(float)
# merge_crime['노령화지수_여지'] = merge_crime['노령화지수_여자'].astype(float)

# %%
merge_crime['면적 당 CCTV 대수(km² 당)'] = round((merge_crime['CCTV_sum'] / merge_crime['면적 (km²)']), 2)
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자  \
# 0  강남구   3  382        385      7721     39.50     6.53    81561    36926
# 1  강동구   0  262        262      3549     24.59     4.06    80131    36613
# 2  강북구   5  240        245      3531     23.60     3.90    65980    28373
# 3  강서구   0  350        350      3612     41.45     6.85    98380    43366
# 4  관악구   3  383        386      5549     29.57     4.89    84596    37422
#
#   노령인구_여자  노령인구_여지  면적 당 CCTV 대수(km² 당)
# 0   44635    44635               195.47
# 1   43518    43518               144.33
# 2   37607    37607               149.62
# 3   55014    55014                87.14
# 4   47174    47174               187.66

# %%
merge_crime['노령인구 당 CCTV 비율(인당) (%)'] = round((merge_crime['CCTV_sum'] / merge_crime['노령인구_전체']) * 100, 2)
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자  \
# 0  강남구   3  382        385      7721     39.50     6.53    81561    36926
# 1  강동구   0  262        262      3549     24.59     4.06    80131    36613
# 2  강북구   5  240        245      3531     23.60     3.90    65980    28373
# 3  강서구   0  350        350      3612     41.45     6.85    98380    43366
# 4  관악구   3  383        386      5549     29.57     4.89    84596    37422
#
#   노령인구_여자  노령인구_여지  면적 당 CCTV 대수(km² 당)  노령인구 당 CCTV 비율(인당) (%)
# 0   44635    44635               195.47                    9.47
# 1   43518    43518               144.33                    4.43
# 2   37607    37607               149.62                    5.35
# 3   55014    55014                87.14                    3.67
# 4   47174    47174               187.66                    6.56

# %%
merge_crime['old_pop_crime'] = round((merge_crime['crime_sum'] / merge_crime['노령인구_전체']) * 100, 2)
merge_crime.head()
# Out:
#     구별  살인   폭력  crime_sum  CCTV_sum  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자  \
# 0  강남구   3  382        385      7721     39.50     6.53    81561    36926
# 1  강동구   0  262        262      3549     24.59     4.06    80131    36613
# 2  강북구   5  240        245      3531     23.60     3.90    65980    28373
# 3  강서구   0  350        350      3612     41.45     6.85    98380    43366
# 4  관악구   3  383        386      5549     29.57     4.89    84596    37422
#
#   노령인구_여자  노령인구_여지  면적 당 CCTV 대수(km² 당)  노령인구 당 CCTV 비율(인당) (%)  old_pop_crime
# 0   44635    44635               195.47                    9.47           0.47
# 1   43518    43518               144.33                    4.43           0.33
# 2   37607    37607               149.62                    5.35           0.37
# 3   55014    55014                87.14                    3.67           0.36
# 4   47174    47174               187.66                    6.56           0.46

# %% [markdown]
# ## data visualization

# %% [markdown]
# ### 구 면적 당 CCTV 대수

# %%
merge_crime_sorted = merge_crime.sort_values(by='면적 당 CCTV 대수(km² 당)', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='면적 당 CCTV 대수(km² 당)')
plt.title("구 면적 당 CCTV 대수")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 성동구, 양천구, 구로구, 중랑구, 금천구 순으로 구 면적당 CCTV 대수가 높다

# %% [markdown]
# ### 노령인구 당 CCTV 비율

# %%
merge_crime_sorted = merge_crime.sort_values(by='노령인구 당 CCTV 비율(인당) (%)', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='노령인구 당 CCTV 비율(인당) (%)')
plt.title("노령인구 당 CCTV 비율(인당) (%)")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 하지만, 노령인구 당 CCTV 비율은 강남구, 성동구, 서초구, 용산구, 종로구 순

# %% [markdown]
# ### 노령화 지수

# %%
# merge_crime_sorted = merge_crime.sort_values(by='노령화지수_합계', ascending=False)

# plt.figure(figsize=(18, 10))
# ax = sns.barplot(data=merge_crime_sorted, x='구별', y='노령화지수_합계')
# plt.title("노령화지수_합계")
# for p in ax.patches:
#     ax.annotate(f'{p.get_height()}', 
#                 (p.get_x() + p.get_width() / 2., p.get_height()), 
#                 ha='center', va='bottom', 
#                 fontsize=10, color='black', 
#                 xytext=(0, 5), 
#                 textcoords='offset points')
# plt.xticks(rotation=45)
# plt.show()

# %% [markdown]
# * 강북구, 관악구, 중구, 도봉구, 금천구

# %% [markdown]
# ### 노령대상 범죄율

# %%
merge_crime_sorted = merge_crime.sort_values(by='old_pop_crime', ascending=True)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='old_pop_crime')
plt.title("Old people about crime (%)")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 성북구, 도봉구, 용산구, 강동구, 서대문구

# %% [markdown]
# ### 죄종

# %%
merge_crime_sorted = merge_crime.sort_values(by='crime_sum', ascending=True)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='crime_sum')
plt.title("Total crime case")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 용산구, 성동구, 도봉구, 성북구, 서대문구
