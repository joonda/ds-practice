# %% [markdown]
# # hypo1 - 노령 인구 대비 CCTV 설치 대수 비율이 높을 수록, 노령 대상 범죄율은 낮을 것이다

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import googlemaps
import seaborn as sns
from matplotlib import rc 
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False

# %%
cctv = pd.read_excel('./data/서울시 자치구 (연도별) CCTV 설치현황_240630.xlsx')
cctv.head()
# Out:
#     순번   구분     총 계  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  \
# 0  NaN    계  102380               11692   8225  10865  10652  12854  11838
# 1  1.0  종로구    2290                 230    100    140    140     66    233
# 2  2.0  중 구    3021                 376    220    366    381    155    357
# 3  3.0  용산구    3300                 106    295    491    147    335    473
# 4  4.0  성동구    4514                 542    278    939    457    640    483
#
#    2021년  2022년  2023년  2024년\n6.30.
# 0   9558   9218  13919          3559
# 1     85    219    919           158
# 2    414    137    135           480
# 3    486    413    492            62
# 4    366    233    471           105

# %%
crime = pd.read_csv("./data/경찰청 서울특별시경찰청_경찰서별 살인 및 폭력 죄종 피해자 성별 및 연령대별 현황_20231231.csv", encoding="cp949")
crime.head()
# Out:
#       구분       연령  피해자 수
# 0  중부 살인   남자6세이하      0
# 1  중부 살인  남자12세이하      0
# 2  중부 살인  남자15세이하      0
# 3  중부 살인  남자20세이하      0
# 4  중부 살인  남자30세이하      1

# %%
area = pd.read_excel('./data/행정구역(구별)_20241014164019.xlsx')
area.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %% [markdown]
# ## data preprocessing

# %% [markdown]
# ### crime

# %%
crime.head()
# Out:
#       구분       연령  피해자 수
# 0  중부 살인   남자6세이하      0
# 1  중부 살인  남자12세이하      0
# 2  중부 살인  남자15세이하      0
# 3  중부 살인  남자20세이하      0
# 4  중부 살인  남자30세이하      1

# %%
drop_idx = crime[(crime['연령'].str.contains('이하')) | (crime['연령'].str.contains('미상'))].index
crime.drop(index=drop_idx, inplace=True)
crime
# Out:
#          구분       연령  피해자 수
# 8     중부 살인  남자60세이상      0
# 18    중부 살인  여자60세이상      1
# 28    중부 폭력  남자60세초과    139
# 38    중부 폭력  여자60세초과     53
# 48    종로 살인  남자60세초과      2
# ...     ...      ...    ...
# 1198  도봉 폭력  여자60세초과     64
# 1208  수서 살인  남자60세초과      0
# 1218  수서 살인  여자60세초과      2
# 1228  수서 폭력  남자60세초과    138
# 1238  수서 폭력  여자60세초과     63
#
# [124 rows x 3 columns]

# %%
station_list = []
crime_sort_list = []
for idx, row in crime.iterrows():
    station = row['구분'].split()[0]
    station_list.append(station)
    crime_sort = row['구분'].split()[1]
    crime_sort_list.append(crime_sort)

crime_sort_list[:5], station_list[:5]
# Out:
# (['살인', '살인', '폭력', '폭력', '살인'], ['중부', '중부', '중부', '중부', '종로'])

# %%
crime['구분'] = station_list
crime['죄종'] = crime_sort_list

crime.head()
# Out:
#     구분       연령  피해자 수  죄종
# 8   중부  남자60세이상      0  살인
# 18  중부  여자60세이상      1  살인
# 28  중부  남자60세초과    139  폭력
# 38  중부  여자60세초과     53  폭력
# 48  종로  남자60세초과      2  살인

# %%
crime_station = crime.groupby(['구분', '죄종'])["피해자 수"].sum().to_frame().reset_index()
crime_station.head()
# Out:
#    구분  죄종  피해자 수
# 0  강남  살인      1
# 1  강남  폭력    181
# 2  강동  살인      0
# 3  강동  폭력    262
# 4  강북  살인      5

# %%
crime_station = crime_station.pivot(index=['구분'], columns=['죄종'], values='피해자 수').reset_index()
crime_station.head()
# Out:
# 죄종  구분  살인   폭력
# 0   강남   1  181
# 1   강동   0  262
# 2   강북   5  240
# 3   강서   0  350
# 4   관악   3  383

# %% [markdown]
# #### google maps api key

# %% [markdown]
# * AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI

# %%
gmaps_key = "AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI"

# %%
gmaps = googlemaps.Client(key=gmaps_key)

# %%
tmp = gmaps.geocode("서울영등포경찰서", language='ko')
tmp
# Out:
# [{'address_components': [{'long_name': '608',
#     'short_name': '608',
#     'types': ['premise']},
#    {'long_name': '국회대로',
#     'short_name': '국회대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-043',
#     'short_name': '150-043',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'geometry': {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5273930802915,
#      'lng': 126.9021580802915},
#     'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ1TimJLaffDURptXOs0Tj6sY',
#   'plus_code': {'compound_code': 'GWG2+C8 대한민국 서울특별시',
#    'global_code': '8Q98GWG2+C8'},
#   'types': ['establishment', 'point_of_interest', 'police']}]

# %%
tmp[0].get('geometry')
# Out:
# {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 37.5273930802915, 'lng': 126.9021580802915},
#   'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}}

# %%
tmp[0].get('geometry')['location']['lat']
# Out:
# 37.5260441

# %%
tmp[0].get('geometry')['location']['lng']
# Out:
# 126.9008091

# %%
tmp[0].get('formatted_address')
# Out:
# '대한민국 서울특별시 영등포구 국회대로 608'

# %%
tmp[0].get('formatted_address').split()[2]
# Out:
# '영등포구'

# %%
crime_station['구분']
# Out:
# 0      강남
# 1      강동
# 2      강북
# 3      강서
# 4      관악
# 5      광진
# 6      구로
# 7      금천
# 8     남대문
# 9      노원
# 10     도봉
# 11    동대문
# 12     동작
# 13     마포
# 14     방배
# 15    서대문
# 16     서부
# 17     서초
# 18     성동
# 19     성북
# 20     송파
# 21     수서
# 22     양천
# 23    영등포
# 24     용산
# 25     은평
# 26     종로
# 27     종암
# 28     중랑
# 29     중부
# 30     혜화
# Name: 구분, dtype: object

# %%
tmp_gu = []
lat_list = []
lng_list = []

for gubun in crime_station['구분']:
    station_name = "서울" + gubun + "경찰서"
    tmp = gmaps.geocode(station_name, language='ko')

    gu = tmp[0].get('formatted_address').split()[2]
    lat = tmp[0].get('geometry')['location']['lat']
    lng = tmp[0].get('geometry')['location']['lng']

    tmp_gu.append(gu)
    lat_list.append(lat)
    lng_list.append(lng)

# %%
tmp_gu[:5], lat_list[:5], lng_list[:5]
# Out:
# (['강남구', '강동구', '강북구', '강서구', '관악구'],
#  [37.5094352, 37.528511, 37.63719740000001, 37.5513622, 37.4743945],
#  [127.0669578, 127.1268224, 127.0273048, 126.8502799, 126.9513489])

# %%
crime_station['구별'] = tmp_gu
crime_station['lat'] = lat_list
crime_station['lng'] = lng_list
crime_station.head()
# Out:
# 죄종  구분  살인   폭력   구별        lat         lng
# 0   강남   1  181  강남구  37.509435  127.066958
# 1   강동   0  262  강동구  37.528511  127.126822
# 2   강북   5  240  강북구  37.637197  127.027305
# 3   강서   0  350  강서구  37.551362  126.850280
# 4   관악   3  383  관악구  37.474395  126.951349

# %%
m = folium.Map(location=[37.5502, 126.982], zoom_start=12)

for idx,row in crime_station.iterrows():
    lat = row['lat']
    lng = row['lng']
    name = row['구분'] + ' 경찰서'

    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(
            color='blue',
            icon_color='white'
        ),
        popup=name
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63dc87dfd145ca7c4547133a182e9598 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63dc87dfd145ca7c4547133a182e9598&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63dc87dfd145ca7c4547133a182e9598 = L.map(
#                 &quot;map_63dc87dfd145ca7c4547133a182e9598&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c5040b233c1e9d2caba4a896db1ccf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5c5040b233c1e9d2caba4a896db1ccf3.addTo(map_63dc87dfd145ca7c4547133a182e9598);
#
#
#             var marker_5910a2ed789a14c0e6dae815368bed8b = L.marker(
#                 [37.5094352, 127.0669578],
#                 {}
#             ).addTo(map_63dc87dfd145ca7c4547133a182e9598);
#
#
#             var icon_c6844308a499d8f6a5e6d68a2ea3a95f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5910a2ed789a14c0e6dae815368bed8b.setIcon(icon_c6844308a499d8f6a5e6d68a2ea3a95f);
#
#
#         var popup_0bdfe6a737ea23ad9b314e30fbab7866 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dc3b45b43e418b3c51dde8e06ba9a10 = $(`&lt;div id=&quot;html_0dc3b45b43e418b3c51dde8e06ba9a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남 경찰서&lt;/div&gt;`)[0];
#                 popup_0bdfe6a737ea23ad9b314e30fbab7866.setContent(html_0dc3b45b43e418b3c51dde8e06ba9a10);
#
#
#
#         marker_5910a2ed789a14c0e6dae815368bed8b.bindPopup(popup_0bdfe6a737ea23ad9b314e30fbab7866)
#         ;
#
#
#
#
#             var marker_e0959be4afb49b4784ba9d8f4450933e = L.marker(
#                 [37.528511, 127.1268224],
#                 {}
#             ).addTo(map_63dc87dfd145ca7c4547133a182e9598);
#
#
#             var icon_c80de3ce94dd3776fca61a84cf815590 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0959be4afb49b4784ba9d8f4450933e.setIcon(icon_c80de3ce94dd3776fca61a84cf815590);
#
#
#         var popup_a16b5f199206a00ff611eb14ea3fd295 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2ce2248b52a1fce2dde9dc5e392d90e = $(`&lt;div id=&quot;html_e2ce2248b52a1fce2dde9dc5e392d90e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동 경찰서&lt;/div&gt;`)[0];
#                 popup_a16b5f199206a00ff611eb14ea3fd295.setContent(html_e2ce2248b52a1fce2dde9dc5e392d90e);
#
#
#
#         marker_e0959be4afb49b4784ba9d8f4450933e.bindPopup(popup_a16b5f199206a00ff611eb14ea3fd295)
#         ;
#
#
#
#
#             var marker_97cfbe735b549c6c021c8f4ec76d5f4c = L.marker(
#                 [37.63719740000001, 127.0273048],
#                 {}
#             ).addTo(map_63dc87dfd145ca7c4547133a182e9598);
#
#
#             var icon_1133c9703d10545c36597e9c5ba1448a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97cfbe735b549c6c021c8f4ec76d5f4c.setIcon(icon_1133c9703d10545c36597e9c5ba1448a);
#
#
#         var popup_5175f80d4bb4c9a073d0d031108c67d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b788ab50f5305ced8d41626d752662e = $(`&lt;div id=&quot;html_6b788ab50f5305ced8d41626d752662e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북 경찰서&lt;/div&gt;`)[0];
#                 popup_5175f80d4bb4c9a073d0d031108c67d2.setContent(html_6b788ab50f5305ced8d41626d752662e);
#
#
#
#         marker_97cfbe735b549c6c021c8f4ec76d5f4c.bindPopup(popup_5175f80d4bb4c9a073d0d031108c67d2)
#         ;
#
#
#
#
#             var marker_52461df6c9e285de2a9b7d7f4af5a9f9 = L.marker(
#                 [37.5513622, 126.8502799],
#                 {}
#             ).addTo(map_63dc87dfd145ca7c4547133a182e9598);
#
#
#             var icon_7aa42a5cbf82ac88159aa30a5fc1ce17 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;marke

# %%
crime_station[crime_station['구별'] == '강남구']
# Out:
# 죄종  구분  살인   폭력   구별        lat         lng
# 0   강남   1  181  강남구  37.509435  127.066958
# 21  수서   2  201  강남구  37.493490  127.077212

# %%
crime_station.drop(columns=['구분', 'lat', 'lng'], inplace=True)

# %%
crime_station = crime_station.groupby('구별').sum().reset_index()
crime_station.head()
# Out:
# 죄종   구별  살인   폭력
# 0   강남구   3  382
# 1   강동구   0  262
# 2   강북구   5  240
# 3   강서구   0  350
# 4   관악구   3  383

# %% [markdown]
# ### cctv

# %%
cctv.drop(index=[0], columns=["순번", "총 계", "2024년\n6.30."], inplace=True)
cctv.reset_index(drop=True, inplace=True)
cctv.head()
# Out:
#     구분  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구                 230    100    140    140     66    233     85    219
# 1  중 구                 376    220    366    381    155    357    414    137
# 2  용산구                 106    295    491    147    335    473    486    413
# 3  성동구                 542    278    939    457    640    483    366    233
# 4  광진구                 403     42    666    460    712    191    740    273
#
#    2023년
# 0    919
# 1    135
# 2    492
# 3    471
# 4    340

# %%
cctv.columns[1:]
# Out:
# Index(['2016년 이전 설치된 CCTV ', '2016년', '2017년', '2018년', '2019년', '2020년',
#        '2021년', '2022년', '2023년'],
#       dtype='object')

# %%
cctv['합계'] = cctv['2016년 이전 설치된 CCTV '] + cctv['2016년'] + cctv['2017년'] + cctv['2018년'] + cctv['2019년'] + cctv['2020년'] + cctv['2021년'] + cctv["2022년"] + cctv['2023년']
cctv.head()
# Out:
#     구분  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구                 230    100    140    140     66    233     85    219
# 1  중 구                 376    220    366    381    155    357    414    137
# 2  용산구                 106    295    491    147    335    473    486    413
# 3  성동구                 542    278    939    457    640    483    366    233
# 4  광진구                 403     42    666    460    712    191    740    273
#
#    2023년    합계
# 0    919  2132
# 1    135  2541
# 2    492  3238
# 3    471  4409
# 4    340  3827

# %%
cctv.rename(columns={"구분" : "구별"}, inplace=True)
cctv = cctv[['구별', '합계']]
cctv.head()
# Out:
#     구별    합계
# 0  종로구  2132
# 1  중 구  2541
# 2  용산구  3238
# 3  성동구  4409
# 4  광진구  3827

# %% [markdown]
# ### area

# %%
area.head()
# Out:
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %%
area.drop(columns='자치구별(1)', index=[0,2], inplace=True)

# %%
area
# Out:
#     자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 1   자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 3       종로구     23.91     3.95     17     87    279   1475
# 4        중구      9.96     1.65     15     74    253   1582
# 5       용산구     21.87     3.61     16     36    357   2601
# 6       성동구     16.82     2.78     17     17    471   3645
# 7       광진구     17.06     2.82     15      7    370   3012
# 8      동대문구     14.22     2.35     14     10    360   2629
# 9       중랑구      18.5     3.06     16      6    558   4232
# 10      성북구     24.58     4.06     20     39    468   3667
# 11      강북구      23.6      3.9     13      4    389   3384
# 12      도봉구     20.65     3.41     14      4    396   2993
# 13      노원구     35.44     5.86     19      5    720   5864
# 14      은평구     29.71     4.91     16     11    574   4250
# 15     서대문구     17.63     2.91     14     20    518   3673
# 16      마포구     23.85     3.94     16     26    418   3281
# 17      양천구     17.41     2.88     18      3    563   4598
# 18      강서구     41.45     6.85     20     13    646   5087
# 19      구로구     20.12     3.32     16     10    629   4926
# 20      금천구     13.02     2.15     10      3    386   2912
# 21     영등포구     24.55     4.06     18     34    583   4922
# 22      동작구     16.36      2.7     15      9    526   3518
# 23      관악구     29.57     4.89     21      3    631   5136
# 24      서초구     46.97     7.76     18     10    560   3821
# 25      강남구      39.5     6.53     22     14    847   5609
# 26      송파구     33.88      5.6     27     13    758   4239
# 27      강동구     24.59     4.06     19      9    621   5446

# %%
area.columns = area.loc[1, :]

# %%
area.drop(index=1, inplace=True)
area.reset_index(drop=True, inplace=True)
area.head()
# Out:
# 1 자치구별(2) 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0     종로구    23.91    3.95  17  87  279  1475
# 1      중구     9.96    1.65  15  74  253  1582
# 2     용산구    21.87    3.61  16  36  357  2601
# 3     성동구    16.82    2.78  17  17  471  3645
# 4     광진구    17.06    2.82  15   7  370  3012

# %%
area.rename(columns={"자치구별(2)" : '구별'}, inplace=True)
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0  종로구    23.91    3.95  17  87  279  1475
# 1   중구     9.96    1.65  15  74  253  1582
# 2  용산구    21.87    3.61  16  36  357  2601
# 3  성동구    16.82    2.78  17  17  471  3645
# 4  광진구    17.06    2.82  15   7  370  3012

# %%
area = area[['구별', '면적 (km²)', '구성비 (%)']]

# %% [markdown]
# ### population

# %%
pop = pd.read_excel('./data/자치구별+고령인구(추계인구)_20241019165325.xlsx')
pop.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)     2023  2023.1  2023.2
# 0  자치구별(1)  자치구별(2)     고령인구    고령인구    고령인구
# 1  자치구별(1)  자치구별(2)       소계      남자      여자
# 2       합계       소계  1691853  749118  942735
# 3      NaN      종로구    27187   11986   15201
# 4      NaN       중구    24374   10637   13737

# %%
pop.drop(index=[0, 1, 2], columns=['자치구별(1)'], inplace=True)
pop.columns = ["구별", "노령인구_전체", "노령인구_남자", "노령인구_여자"]
pop.reset_index(drop=True, inplace=True)

# %%
pop.head()
# Out:
#     구별 노령인구_전체 노령인구_남자 노령인구_여자
# 0  종로구   27187   11986   15201
# 1   중구   24374   10637   13737
# 2  용산구   37740   16395   21345
# 3  성동구   47907   21034   26873
# 4  광진구   55697   24952   30745

# %% [markdown]
# ### old-point

# %%
old_point = pd.read_excel('./data/자치구별+노령화지수(추계인구)_20240929181758.xlsx')
old_point.head()
# Out:
#    자치구별(1)  자치구별(2)   2023 2023.1 2023.2
# 0  자치구별(1)  자치구별(2)     합계     남자     여자
# 1       합계       소계  199.1  171.6  228.2
# 2      NaN      종로구  267.8  237.3    298
# 3      NaN       중구  286.5  245.3  329.3
# 4      NaN      용산구  200.7  172.2    230

# %%
old_point.drop(index=[0, 1], columns=["자치구별(1)"], inplace=True)
old_point.columns = ['구별', '노령화지수_합계', '노령화지수_남자', '노령화지수_여자']
old_point.reset_index(drop=True, inplace=True)
old_point.head()
# Out:
#     구별 노령화지수_합계 노령화지수_남자 노령화지수_여자
# 0  종로구    267.8    237.3      298
# 1   중구    286.5    245.3    329.3
# 2  용산구    200.7    172.2      230
# 3  성동구    193.4    167.5    219.9
# 4  광진구    211.1    183.7    240.1

# %% [markdown]
# ### concat

# %%
cctv.head()
# Out:
#     구별    합계
# 0  종로구  2132
# 1  중 구  2541
# 2  용산구  3238
# 3  성동구  4409
# 4  광진구  3827

# %%
crime_station.head()
# Out:
# 죄종   구별  살인   폭력
# 0   강남구   3  382
# 1   강동구   0  262
# 2   강북구   5  240
# 3   강서구   0  350
# 4   관악구   3  383

# %%
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)
# 0  종로구    23.91    3.95
# 1   중구     9.96    1.65
# 2  용산구    21.87    3.61
# 3  성동구    16.82    2.78
# 4  광진구    17.06    2.82

# %%
pop.head()
# Out:
#     구별 노령인구_전체 노령인구_남자 노령인구_여자
# 0  종로구   27187   11986   15201
# 1   중구   24374   10637   13737
# 2  용산구   37740   16395   21345
# 3  성동구   47907   21034   26873
# 4  광진구   55697   24952   30745

# %%
old_point.head()
# Out:
#     구별 노령화지수_합계 노령화지수_남자 노령화지수_여자
# 0  종로구    267.8    237.3      298
# 1   중구    286.5    245.3    329.3
# 2  용산구    200.7    172.2      230
# 3  성동구    193.4    167.5    219.9
# 4  광진구    211.1    183.7    240.1

# %%
merge_crime = pd.merge(crime_station, cctv, left_on='구별', right_on='구별', how='inner')
merge_crime.head()
# Out:
#     구별  살인   폭력    합계
# 0  강남구   3  382  7721
# 1  강동구   0  262  3549
# 2  강북구   5  240  3531
# 3  강서구   0  350  3612
# 4  관악구   3  383  5549

# %%
merge_crime = pd.merge(merge_crime, area, on='구별')
merge_crime.head()
# Out:
#     구별  살인   폭력    합계 면적 (km²) 구성비 (%)
# 0  강남구   3  382  7721     39.5    6.53
# 1  강동구   0  262  3549    24.59    4.06
# 2  강북구   5  240  3531     23.6     3.9
# 3  강서구   0  350  3612    41.45    6.85
# 4  관악구   3  383  5549    29.57    4.89

# %%
merge_crime = pd.merge(merge_crime, pop, on='구별')
merge_crime.head()
# Out:
#     구별  살인   폭력    합계 면적 (km²) 구성비 (%) 노령인구_전체 노령인구_남자 노령인구_여자
# 0  강남구   3  382  7721     39.5    6.53   81561   36926   44635
# 1  강동구   0  262  3549    24.59    4.06   80131   36613   43518
# 2  강북구   5  240  3531     23.6     3.9   65980   28373   37607
# 3  강서구   0  350  3612    41.45    6.85   98380   43366   55014
# 4  관악구   3  383  5549    29.57    4.89   84596   37422   47174

# %%
merge_crime = pd.merge(merge_crime, old_point, on='구별')
merge_crime.head()
# Out:
#     구별  살인   폭력    합계 면적 (km²) 구성비 (%) 노령인구_전체 노령인구_남자 노령인구_여자 노령화지수_합계  \
# 0  강남구   3  382  7721     39.5    6.53   81561   36926   44635    142.3
# 1  강동구   0  262  3549    24.59    4.06   80131   36613   43518    165.6
# 2  강북구   5  240  3531     23.6     3.9   65980   28373   37607    321.1
# 3  강서구   0  350  3612    41.45    6.85   98380   43366   55014    192.5
# 4  관악구   3  383  5549    29.57    4.89   84596   37422   47174    300.5
#
#   노령화지수_남자 노령화지수_여자
# 0    123.6    162.7
# 1    145.6    187.3
# 2    270.2    374.2
# 3      166    220.3
# 4    257.4    346.4

# %%
merge_crime['면적 (km²)'] = merge_crime['면적 (km²)'].astype(float) 
merge_crime['구성비 (%)'] = merge_crime['구성비 (%)'].astype(float)
merge_crime['노령인구_전체'] = merge_crime['노령인구_전체'].astype(int)
merge_crime['노령인구_남자'] = merge_crime['노령인구_남자'].astype(int)
merge_crime['노령인구_여지'] = merge_crime['노령인구_여자'].astype(int)
merge_crime['노령화지수_합계'] = merge_crime['노령화지수_합계'].astype(float)
merge_crime['노령화지수_남자'] = merge_crime['노령화지수_남자'].astype(float)
merge_crime['노령화지수_여지'] = merge_crime['노령화지수_여자'].astype(float)

# %%
merge_crime['면적 당 CCTV 대수(km² 당)'] = round((merge_crime['합계'] / merge_crime['면적 (km²)']), 2)
merge_crime.head()
# Out:
#     구별  살인   폭력    합계  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자 노령인구_여자  노령화지수_합계  \
# 0  강남구   3  382  7721     39.50     6.53    81561    36926   44635     142.3
# 1  강동구   0  262  3549     24.59     4.06    80131    36613   43518     165.6
# 2  강북구   5  240  3531     23.60     3.90    65980    28373   37607     321.1
# 3  강서구   0  350  3612     41.45     6.85    98380    43366   55014     192.5
# 4  관악구   3  383  5549     29.57     4.89    84596    37422   47174     300.5
#
#    노령화지수_남자 노령화지수_여자  노령인구_여지  노령화지수_여지  면적 당 CCTV 대수(km² 당)
# 0     123.6    162.7    44635     162.7               195.47
# 1     145.6    187.3    43518     187.3               144.33
# 2     270.2    374.2    37607     374.2               149.62
# 3     166.0    220.3    55014     220.3                87.14
# 4     257.4    346.4    47174     346.4               187.66

# %%
merge_crime['노령인구 당 CCTV 비율(인당) (%)'] = round((merge_crime['합계'] / merge_crime['노령인구_전체']) * 100, 2)
merge_crime.head()
# Out:
#     구별  살인   폭력    합계  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자 노령인구_여자  노령화지수_합계  \
# 0  강남구   3  382  7721     39.50     6.53    81561    36926   44635     142.3
# 1  강동구   0  262  3549     24.59     4.06    80131    36613   43518     165.6
# 2  강북구   5  240  3531     23.60     3.90    65980    28373   37607     321.1
# 3  강서구   0  350  3612     41.45     6.85    98380    43366   55014     192.5
# 4  관악구   3  383  5549     29.57     4.89    84596    37422   47174     300.5
#
#    노령화지수_남자 노령화지수_여자  노령인구_여지  노령화지수_여지  면적 당 CCTV 대수(km² 당)  \
# 0     123.6    162.7    44635     162.7               195.47
# 1     145.6    187.3    43518     187.3               144.33
# 2     270.2    374.2    37607     374.2               149.62
# 3     166.0    220.3    55014     220.3                87.14
# 4     257.4    346.4    47174     346.4               187.66
#
#    노령인구 당 CCTV 비율(인당) (%)
# 0                    9.47
# 1                    4.43
# 2                    5.35
# 3                    3.67
# 4                    6.56

# %% [markdown]
# ## data visualization

# %% [markdown]
# ### 구 면적 당 CCTV 대수

# %%
merge_crime_sorted = merge_crime.sort_values(by='면적 당 CCTV 대수(km² 당)', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='면적 당 CCTV 대수(km² 당)')
plt.title("구 면적 당 CCTV 대수")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 성동구, 양천구, 구로구, 중랑구, 금천구 순으로 구 면적당 CCTV 대수가 높다

# %% [markdown]
# ### 노령인구 당 CCTV 비율

# %%
merge_crime_sorted = merge_crime.sort_values(by='노령인구 당 CCTV 비율(인당) (%)', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='노령인구 당 CCTV 비율(인당) (%)')
plt.title("노령인구 당 CCTV 비율(인당) (%)")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 하지만, 노령인구 당 CCTV 비율은 강남구, 성동구, 서초구, 용산구, 종로구 순

# %% [markdown]
# ### 노령화 지수

# %%
merge_crime_sorted = merge_crime.sort_values(by='노령화지수_합계', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='노령화지수_합계')
plt.title("노령화지수_합계")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 강북구, 관악구, 중구, 도봉구, 금천구

# %% [markdown]
# ### 죄종

# %%
merge_crime['발생 총계'] = merge_crime['살인'] + merge_crime['폭력']
merge_crime['발생 총계'] = merge_crime['발생 총계'].astype(int)
merge_crime.head()
# Out:
#     구별  살인   폭력    합계  면적 (km²)  구성비 (%)  노령인구_전체  노령인구_남자 노령인구_여자  노령화지수_합계  \
# 0  강남구   3  382  7721     39.50     6.53    81561    36926   44635     142.3
# 1  강동구   0  262  3549     24.59     4.06    80131    36613   43518     165.6
# 2  강북구   5  240  3531     23.60     3.90    65980    28373   37607     321.1
# 3  강서구   0  350  3612     41.45     6.85    98380    43366   55014     192.5
# 4  관악구   3  383  5549     29.57     4.89    84596    37422   47174     300.5
#
#    노령화지수_남자 노령화지수_여자  노령인구_여지  노령화지수_여지  면적 당 CCTV 대수(km² 당)  \
# 0     123.6    162.7    44635     162.7               195.47
# 1     145.6    187.3    43518     187.3               144.33
# 2     270.2    374.2    37607     374.2               149.62
# 3     166.0    220.3    55014     220.3                87.14
# 4     257.4    346.4    47174     346.4               187.66
#
#    노령인구 당 CCTV 비율(인당) (%)  발생 총계
# 0                    9.47    385
# 1                    4.43    262
# 2                    5.35    245
# 3                    3.67    350
# 4                    6.56    386

# %%
merge_crime_sorted = merge_crime.sort_values(by='발생 총계', ascending=True)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='발생 총계')
plt.title("발생 총계")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * 용산구, 성동구, 도봉구, 성북구, 서대문구
