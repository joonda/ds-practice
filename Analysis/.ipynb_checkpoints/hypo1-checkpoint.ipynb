# %% [markdown]
# # hypo1 - 구 면적 당 CCTV 설치 대수가 많을 수록, 해당 구 범죄율은 낮을 것이다

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import googlemaps
import seaborn as sns
from matplotlib import rc 
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False

# %%
cctv = pd.read_excel("./data/서울시 안심이 CCTV 연계 현황.xlsx")
cctv.head()
# Out:
#    자치구                                     안심 주소       위도        경도  CCTV 수량  \
# 0  중랑구    면목3.8동 산16-2 (서일대뒷산공원-화장실)_C-MM38-0001  37.5879  127.0987        1
# 1  중랑구       면목3.8동1064-9 (재개발조합사무실)_C-MM38-0022  37.5819  127.0944        1
# 2  중랑구   면목3.8동 산16-2 (서일대뒷산공원-체육시설)_C-MM38-0025  37.5876  127.0989        1
# 3  중랑구  면목4동 1342-14 (다사랑어린이집앞 공원인도)_C-MM04-0046  37.5717  127.0863        1
# 4  중랑구              면목4동 1382 (고정)_C-MM04-0038-A  37.5738  127.0870        1
#
#        수정 일시
# 0 2022-12-01
# 1 2022-12-01
# 2 2022-12-01
# 3 2022-12-01
# 4 2022-12-01

# %%
crime = pd.read_csv("./data/경찰청 서울특별시경찰청_경찰서별 5대범죄 발생 검거 현황_20221231.csv", encoding="cp949")
crime.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    1
# 1  중부     살인   검거    2
# 2  중부     강도   발생    3
# 3  중부     강도   검거    2
# 4  중부  강간,추행   발생  137

# %%
area = pd.read_excel('./data/행정구역(구별)_20241014164019.xlsx')
area.head()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %% [markdown]
# ## data preprocessing

# %% [markdown]
# ### crime

# %%
crime.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    1
# 1  중부     살인   검거    2
# 2  중부     강도   발생    3
# 3  중부     강도   검거    2
# 4  중부  강간,추행   발생  137

# %%
crime_state = crime.pivot(index=['구분'], columns=['죄종', '발생검거'], values='건수')
crime_state.reset_index(inplace=True)
crime_state.head()
# Out:
# 죄종    구분    살인        강도       강간,추행             절도              폭력          \
# 발생검거        발생   검거   발생   검거     발생     검거      발생      검거      발생      검거
# 0     강남   6.0  5.0  9.0  8.0  458.0  359.0  1565.0   654.0  2494.0  2178.0
# 1     강동   5.0  6.0  5.0  5.0  157.0  134.0  1672.0   900.0  1872.0  1599.0
# 2     강북   5.0  4.0  5.0  6.0  177.0  147.0   872.0   589.0  1773.0  1597.0
# 3     강서   3.0  3.0  7.0  7.0  261.0  195.0  1991.0  1185.0  2401.0  2201.0
# 4     관악  10.0  8.0  9.0  8.0  327.0  279.0  1966.0  1050.0  2567.0  2066.0
#
# 죄종    강간
# 발생검거  발생  검거
# 0    NaN NaN
# 1    NaN NaN
# 2    NaN NaN
# 3    NaN NaN
# 4    NaN NaN

# %%
crime_state.columns
# Out:
# MultiIndex([(   '구분',   ''),
#             (   '살인', '발생'),
#             (   '살인', '검거'),
#             (   '강도', '발생'),
#             (   '강도', '검거'),
#             ('강간,추행', '발생'),
#             ('강간,추행', '검거'),
#             (   '절도', '발생'),
#             (   '절도', '검거'),
#             (   '폭력', '발생'),
#             (   '폭력', '검거'),
#             (   '강간', '발생'),
#             (   '강간', '검거')],
#            names=['죄종', '발생검거'])

# %%
col_list = []
for col in crime_state.columns:
    col_list.append(col[0] + col[1])

col_list[:5]
# Out:
# ['구분', '살인발생', '살인검거', '강도발생', '강도검거']

# %%
crime_state.columns = col_list
crime_state.head()
# Out:
#    구분  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생    절도검거    폭력발생  \
# 0  강남   6.0   5.0   9.0   8.0    458.0    359.0  1565.0   654.0  2494.0
# 1  강동   5.0   6.0   5.0   5.0    157.0    134.0  1672.0   900.0  1872.0
# 2  강북   5.0   4.0   5.0   6.0    177.0    147.0   872.0   589.0  1773.0
# 3  강서   3.0   3.0   7.0   7.0    261.0    195.0  1991.0  1185.0  2401.0
# 4  관악  10.0   8.0   9.0   8.0    327.0    279.0  1966.0  1050.0  2567.0
#
#      폭력검거  강간발생  강간검거
# 0  2178.0   NaN   NaN
# 1  1599.0   NaN   NaN
# 2  1597.0   NaN   NaN
# 3  2201.0   NaN   NaN
# 4  2066.0   NaN   NaN

# %%
crime_state[crime_state['강간,추행발생'].isna()]
# Out:
#     구분  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생   절도검거    폭력발생  \
# 10  도봉   3.0   3.0   0.0   0.0      NaN      NaN   969.0  546.0  1099.0
# 14  방배   1.0   1.0   0.0   0.0      NaN      NaN   305.0  188.0   391.0
# 19  성북   1.0   1.0   0.0   0.0      NaN      NaN   540.0  335.0   732.0
# 22  양천   2.0   2.0   3.0   3.0      NaN      NaN  1474.0  781.0  1576.0
# 27  종암   2.0   2.0   1.0   1.0      NaN      NaN   603.0  380.0   712.0
#
#       폭력검거   강간발생  강간검거
# 10   966.0   70.0  54.0
# 14   355.0   61.0  46.0
# 19   653.0  103.0  78.0
# 22  1252.0  114.0  92.0
# 27   624.0   55.0  51.0

# %%
crime_state.loc[crime_state['강간,추행발생'].isna(), '강간,추행발생'] = crime_state.loc[crime_state['강간,추행발생'].isna().index, '강간발생']
crime_state.loc[crime_state['강간,추행검거'].isna(), '강간,추행검거'] = crime_state.loc[crime_state['강간,추행검거'].isna().index, '강간검거']

# %%
crime_state.drop(columns=['강간발생', '강간검거'], inplace=True)
crime_state.head()
# Out:
#    구분  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생    절도검거    폭력발생  \
# 0  강남   6.0   5.0   9.0   8.0    458.0    359.0  1565.0   654.0  2494.0
# 1  강동   5.0   6.0   5.0   5.0    157.0    134.0  1672.0   900.0  1872.0
# 2  강북   5.0   4.0   5.0   6.0    177.0    147.0   872.0   589.0  1773.0
# 3  강서   3.0   3.0   7.0   7.0    261.0    195.0  1991.0  1185.0  2401.0
# 4  관악  10.0   8.0   9.0   8.0    327.0    279.0  1966.0  1050.0  2567.0
#
#      폭력검거
# 0  2178.0
# 1  1599.0
# 2  1597.0
# 3  2201.0
# 4  2066.0

# %% [markdown]
# #### google maps api key

# %% [markdown]
# * AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI

# %%
gmaps_key = "AIzaSyCYVw0mZyuerDeiYCyY8WNzA22T3DOuzTI"

# %%
gmaps = googlemaps.Client(key=gmaps_key)

# %%
tmp = gmaps.geocode("서울영등포경찰서", language='ko')
tmp
# Out:
# [{'address_components': [{'long_name': '608',
#     'short_name': '608',
#     'types': ['premise']},
#    {'long_name': '국회대로',
#     'short_name': '국회대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-043',
#     'short_name': '150-043',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 국회대로 608',
#   'geometry': {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5273930802915,
#      'lng': 126.9021580802915},
#     'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}},
# ...

# %%
tmp[0].get('geometry')
# Out:
# {'location': {'lat': 37.5260441, 'lng': 126.9008091},
#  'location_type': 'ROOFTOP',
#  'viewport': {'northeast': {'lat': 37.5273930802915, 'lng': 126.9021580802915},
#   'southwest': {'lat': 37.5246951197085, 'lng': 126.8994601197085}}}

# %%
tmp[0].get('geometry')['location']['lat']
# Out:
# 37.5260441

# %%
tmp[0].get('geometry')['location']['lng']
# Out:
# 126.9008091

# %%
tmp[0].get('formatted_address')
# Out:
# '대한민국 서울특별시 영등포구 국회대로 608'

# %%
tmp[0].get('formatted_address').split()[2]
# Out:
# '영등포구'

# %%
crime_state['구분']
# Out:
# 0      강남
# 1      강동
# 2      강북
# 3      강서
# 4      관악
# 5      광진
# 6      구로
# 7      금천
# 8     남대문
# 9      노원
# 10     도봉
# 11    동대문
# 12     동작
# 13     마포
# 14     방배
# 15    서대문
# 16     서부
# 17     서초
# 18     성동
# 19     성북
# 20     송파
# 21     수서
# 22     양천
# 23    영등포
# 24     용산
# 25     은평
# 26     종로
# 27     종암
# 28     중랑
# 29     중부
# 30     혜화
# Name: 구분, dtype: object

# %%
tmp_gu = []
lat_list = []
lng_list = []

for gubun in crime_state['구분']:
    station_name = "서울" + gubun + "경찰서"
    tmp = gmaps.geocode(station_name, language='ko')

    gu = tmp[0].get('formatted_address').split()[2]
    lat = tmp[0].get('geometry')['location']['lat']
    lng = tmp[0].get('geometry')['location']['lng']

    tmp_gu.append(gu)
    lat_list.append(lat)
    lng_list.append(lng)

# %%
tmp_gu[:5], lat_list[:5], lng_list[:5]
# Out:
# (['강남구', '강동구', '강북구', '강서구', '관악구'],
#  [37.5094352, 37.528511, 37.63719740000001, 37.5513622, 37.4743945],
#  [127.0669578, 127.1268224, 127.0273048, 126.8502799, 126.9513489])

# %%
crime_state['구별'] = tmp_gu
crime_state['lat'] = lat_list
crime_state['lng'] = lng_list
crime_state
# Out:
#      구분  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생    절도검거    폭력발생  \
# 0    강남   6.0   5.0   9.0   8.0    458.0    359.0  1565.0   654.0  2494.0
# 1    강동   5.0   6.0   5.0   5.0    157.0    134.0  1672.0   900.0  1872.0
# 2    강북   5.0   4.0   5.0   6.0    177.0    147.0   872.0   589.0  1773.0
# 3    강서   3.0   3.0   7.0   7.0    261.0    195.0  1991.0  1185.0  2401.0
# 4    관악  10.0   8.0   9.0   8.0    327.0    279.0  1966.0  1050.0  2567.0
# 5    광진   6.0   5.0   0.0   0.0    230.0    174.0  1670.0   831.0  1713.0
# 6    구로  11.0  11.0   8.0   9.0    217.0    145.0  1565.0   841.0  2056.0
# 7    금천   2.0   1.0   3.0   3.0    127.0     87.0  1118.0   662.0  1327.0
# 8   남대문   0.0   0.0   2.0   2.0     57.0     36.0   455.0   265.0   480.0
# 9    노원   3.0   3.0   3.0   1.0    180.0    151.0  1504.0   729.0  2206.0
# 10   도봉   3.0   3.0   0.0   0.0     70.0     54.0   969.0   546.0  1099.0
# 11  동대문   4.0   4.0   2.0   2.0    125.0    106.0  1556.0   823.0  1566.0
# ...

# %%
crime_state['구별'].value_counts()
# Out:
# 구별
# 강남구     2
# 종로구     2
# 성북구     2
# 중구      2
# 은평구     2
# 서초구     2
# 마포구     1
# 용산구     1
# 영등포구    1
# 양천구     1
# 송파구     1
# 성동구     1
# 서대문구    1
# 동작구     1
# 강동구     1
# 동대문구    1
# 도봉구     1
# 노원구     1
# 금천구     1
# 구로구     1
# 광진구     1
# 관악구     1
# 강서구     1
# 강북구     1
# 중랑구     1
# Name: count, dtype: int64

# %%
m = folium.Map(location=[37.5502, 126.982], zoom_start=12)

for idx,row in crime_state.iterrows():
    lat = row['lat']
    lng = row['lng']
    name = row['구분'] + ' 경찰서'

    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(
            color='blue',
            icon_color='white'
        ),
        popup=name
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
crime_state[crime_state['구별'] == '강남구']
# Out:
#     구분  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생   절도검거    폭력발생  \
# 0   강남   6.0   5.0   9.0   8.0    458.0    359.0  1565.0  654.0  2494.0
# 21  수서   6.0   5.0   2.0   2.0    209.0    175.0   930.0  553.0  1268.0
#
#       폭력검거   구별        lat         lng
# 0   2178.0  강남구  37.509435  127.066958
# 21  1081.0  강남구  37.493490  127.077212

# %%
crime_state.drop(columns=['구분', 'lat', 'lng'], inplace=True)

# %%
crime_state = crime_state.groupby('구별').sum().reset_index()
crime_state
# Out:
#       구별  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생    절도검거    폭력발생  \
# 0    강남구  12.0  10.0  11.0  10.0    667.0    534.0  2495.0  1207.0  3762.0
# 1    강동구   5.0   6.0   5.0   5.0    157.0    134.0  1672.0   900.0  1872.0
# 2    강북구   5.0   4.0   5.0   6.0    177.0    147.0   872.0   589.0  1773.0
# 3    강서구   3.0   3.0   7.0   7.0    261.0    195.0  1991.0  1185.0  2401.0
# 4    관악구  10.0   8.0   9.0   8.0    327.0    279.0  1966.0  1050.0  2567.0
# 5    광진구   6.0   5.0   0.0   0.0    230.0    174.0  1670.0   831.0  1713.0
# 6    구로구  11.0  11.0   8.0   9.0    217.0    145.0  1565.0   841.0  2056.0
# 7    금천구   2.0   1.0   3.0   3.0    127.0     87.0  1118.0   662.0  1327.0
# 8    노원구   3.0   3.0   3.0   1.0    180.0    151.0  1504.0   729.0  2206.0
# 9    도봉구   3.0   3.0   0.0   0.0     70.0     54.0   969.0   546.0  1099.0
# 10  동대문구   4.0   4.0   2.0   2.0    125.0    106.0  1556.0   823.0  1566.0
# ...

# %%
crime_state['살인검거율'] = round((crime_state['살인검거'] / crime_state['살인발생']) * 100, 2)
crime_state['강도검거율'] = round((crime_state['강도검거'] / crime_state['강도발생']) * 100, 2)
crime_state['강간,추행검거율'] = round((crime_state['강간,추행검거'] / crime_state['강간,추행발생']) * 100, 2)
crime_state['절도검거율'] = round((crime_state['절도검거'] / crime_state['절도발생']) * 100, 2)
crime_state['폭력검거율'] = round((crime_state['폭력검거'] / crime_state['폭력발생']) * 100, 2)

crime_state.head()
# Out:
#     구별  살인발생  살인검거  강도발생  강도검거  강간,추행발생  강간,추행검거    절도발생    절도검거    폭력발생  \
# 0  강남구  12.0  10.0  11.0  10.0    667.0    534.0  2495.0  1207.0  3762.0
# 1  강동구   5.0   6.0   5.0   5.0    157.0    134.0  1672.0   900.0  1872.0
# 2  강북구   5.0   4.0   5.0   6.0    177.0    147.0   872.0   589.0  1773.0
# 3  강서구   3.0   3.0   7.0   7.0    261.0    195.0  1991.0  1185.0  2401.0
# 4  관악구  10.0   8.0   9.0   8.0    327.0    279.0  1966.0  1050.0  2567.0
#
#      폭력검거   살인검거율   강도검거율  강간,추행검거율  절도검거율  폭력검거율
# 0  3259.0   83.33   90.91     80.06  48.38  86.63
# 1  1599.0  120.00  100.00     85.35  53.83  85.42
# 2  1597.0   80.00  120.00     83.05  67.55  90.07
# 3  2201.0  100.00  100.00     74.71  59.52  91.67
# 4  2066.0   80.00   88.89     85.32  53.41  80.48

# %%
crime_state.columns
# Out:
# Index(['구별', '살인발생', '살인검거', '강도발생', '강도검거', '강간,추행발생', '강간,추행검거', '절도발생',
#        '절도검거', '폭력발생', '폭력검거', '살인검거율', '강도검거율', '강간,추행검거율', '절도검거율', '폭력검거율'],
#       dtype='object')

# %%
crime_state = crime_state[['구별', '살인발생', '살인검거','살인검거율', '강도발생', '강도검거', '강도검거율', '강간,추행발생', '강간,추행검거', '강간,추행검거율', 
                           '절도발생', '절도검거', '절도검거율', '폭력발생', '폭력검거', '폭력검거율']]

# %%
crime_state.loc[crime_state['살인검거율'] > 100, '살인검거율'] = 100
crime_state.loc[crime_state['강도검거율'] > 100, '강도검거율'] = 100
crime_state.loc[crime_state['강간,추행검거율'] > 100, '강간,추행검거율'] = 100
crime_state.loc[crime_state['절도검거율'] > 100, '절도검거율'] = 100
crime_state.loc[crime_state['폭력검거율'] > 100, '폭력검거율'] = 100
crime_state.fillna(0)

crime_state.head()
# Out:
#     구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0  강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1  강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2  강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3  강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4  관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
#
#      절도발생    절도검거  절도검거율    폭력발생    폭력검거  폭력검거율
# 0  2495.0  1207.0  48.38  3762.0  3259.0  86.63
# 1  1672.0   900.0  53.83  1872.0  1599.0  85.42
# 2   872.0   589.0  67.55  1773.0  1597.0  90.07
# 3  1991.0  1185.0  59.52  2401.0  2201.0  91.67
# 4  1966.0  1050.0  53.41  2567.0  2066.0  80.48

# %%
crime_state['평균검거율'] = (crime_state['살인검거율'] + crime_state['강도검거율'] + 
                        crime_state['강간,추행검거율'] + crime_state['절도검거율'] + crime_state['폭력검거율']) / 5 
crime_state.head()
# Out:
# /var/folders/76/295r32t542b3jtvsn34n34s00000gn/T/ipykernel_2636/3062892128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_state['평균검거율'] = (crime_state['살인검거율'] + crime_state['강도검거율'] +
#     구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0  강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1  강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2  강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3  강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4  관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
#
#      절도발생    절도검거  절도검거율    폭력발생    폭력검거  폭력검거율   평균검거율
# ...

# %%
crime_state
# Out:
#       구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0    강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1    강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2    강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3    강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4    관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
# 5    광진구   6.0   5.0   83.33   0.0   0.0     NaN    230.0    174.0     75.65
# 6    구로구  11.0  11.0  100.00   8.0   9.0  100.00    217.0    145.0     66.82
# 7    금천구   2.0   1.0   50.00   3.0   3.0  100.00    127.0     87.0     68.50
# 8    노원구   3.0   3.0  100.00   3.0   1.0   33.33    180.0    151.0     83.89
# 9    도봉구   3.0   3.0  100.00   0.0   0.0     NaN     70.0     54.0     77.14
# 10  동대문구   4.0   4.0  100.00   2.0   2.0  100.00    125.0    106.0     84.80
# ...

# %% [markdown]
# ### cctv

# %%
cctv.head()
# Out:
#    자치구                                     안심 주소       위도        경도  CCTV 수량  \
# 0  중랑구    면목3.8동 산16-2 (서일대뒷산공원-화장실)_C-MM38-0001  37.5879  127.0987        1
# 1  중랑구       면목3.8동1064-9 (재개발조합사무실)_C-MM38-0022  37.5819  127.0944        1
# 2  중랑구   면목3.8동 산16-2 (서일대뒷산공원-체육시설)_C-MM38-0025  37.5876  127.0989        1
# 3  중랑구  면목4동 1342-14 (다사랑어린이집앞 공원인도)_C-MM04-0046  37.5717  127.0863        1
# 4  중랑구              면목4동 1382 (고정)_C-MM04-0038-A  37.5738  127.0870        1
#
#        수정 일시
# 0 2022-12-01
# 1 2022-12-01
# 2 2022-12-01
# 3 2022-12-01
# 4 2022-12-01

# %%
cctv['CCTV 수량'].value_counts()
# Out:
# CCTV 수량
# 1    83488
# 2      219
# 3       24
# 5        1
# 6        1
# 4        1
# Name: count, dtype: int64

# %%
cctv[cctv['CCTV 수량'] != 1]
# Out:
#         자치구                                         안심 주소       위도        경도  \
# 9669    은평구                             응암2동 397-144(늘봄이)  37.5914  126.9197
# 11659   은평구                                 갈현2동 517-7 /3  37.6041  126.9299
# 37278  서대문구                         서06-143 홍은사거리(통일로483)  37.5911  126.9414
# 67505   강서구                            C111011_가양1동 130-3  37.5672  126.8424
# 67530   강서구  C111007_가양1동 1460 한강타운아파트 111동 앞 산책로 (허준로23)  37.5720  126.8464
# ...     ...                                           ...      ...       ...
# 70531   강서구                  S292006_화곡6동 1130-37(등서초등학교)  37.5512  126.8536
# 70543   강서구      S312003(A3020)_(도로방범)화곡본동 102-21(화일초등학교)  37.5401  126.8465
# 70548   강서구       S312004(A3025)_(어린이)화곡본동 24-281(화곡초등학교)  37.5436  126.8466
# 77502   강남구                                    대치4-225-01  37.5011  127.0588
# 83428   강남구                                    대치2-231-01  37.4953  127.0668
#
#        CCTV 수량      수정 일시
# ...

# %%
cctv_sum = cctv.groupby('자치구')['CCTV 수량'].sum().to_frame()
cctv_sum
# Out:
#       CCTV 수량
# 자치구
# 강남구      7009
# 강동구      3191
# 강북구      2858
# 강서구      3481
# 관악구      5366
# 광진구      4091
# 구로구      4050
# 금천구      2725
# 노원구      2655
# 도봉구      1598
# 동대문구     2857
# 동작구      2650
# 마포구      2450
# 서대문구     3224
# 서초구      5060
# 성동구      4036
# 성북구      3943
# 송파구      3094
# 양천구      3845
# 영등포구     2899
# 용산구      1078
# 은평구      4116
# 종로구      1930
# 중구       2336
# 중랑구      3471

# %%
cctv_sum.reset_index(inplace=True)
cctv_sum.head()
# Out:
#    자치구  CCTV 수량
# 0  강남구     7009
# 1  강동구     3191
# 2  강북구     2858
# 3  강서구     3481
# 4  관악구     5366

# %% [markdown]
# ### area

# %%
area.head()
# Out:
#    자치구별(1)  자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 0  자치구별(1)  자치구별(2)        면적       면적  동 (개)  동 (개)  통 (개)  반 (개)
# 1  자치구별(1)  자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 2      서울시       소계    605.21      100    426    467  12881  96502
# 3      NaN      종로구     23.91     3.95     17     87    279   1475
# 4      NaN       중구      9.96     1.65     15     74    253   1582

# %%
area.drop(columns='자치구별(1)', index=[0,2], inplace=True)

# %%
area
# Out:
#     자치구별(2)      2022   2022.1 2022.2 2022.3 2022.4 2022.5
# 1   자치구별(2)  면적 (km²)  구성비 (%)     행정     법정     소계     소계
# 3       종로구     23.91     3.95     17     87    279   1475
# 4        중구      9.96     1.65     15     74    253   1582
# 5       용산구     21.87     3.61     16     36    357   2601
# 6       성동구     16.82     2.78     17     17    471   3645
# 7       광진구     17.06     2.82     15      7    370   3012
# 8      동대문구     14.22     2.35     14     10    360   2629
# 9       중랑구      18.5     3.06     16      6    558   4232
# 10      성북구     24.58     4.06     20     39    468   3667
# 11      강북구      23.6      3.9     13      4    389   3384
# 12      도봉구     20.65     3.41     14      4    396   2993
# 13      노원구     35.44     5.86     19      5    720   5864
# 14      은평구     29.71     4.91     16     11    574   4250
# 15     서대문구     17.63     2.91     14     20    518   3673
# 16      마포구     23.85     3.94     16     26    418   3281
# ...

# %%
area.columns = area.loc[1, :]

# %%
area.drop(index=1, inplace=True)
area.reset_index(drop=True, inplace=True)
area.head()
# Out:
# 1  자치구별(2) 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0      종로구    23.91    3.95  17  87  279  1475
# 1       중구     9.96    1.65  15  74  253  1582
# 2      용산구    21.87    3.61  16  36  357  2601
# 3      성동구    16.82    2.78  17  17  471  3645
# 4      광진구    17.06    2.82  15   7  370  3012
# 5     동대문구    14.22    2.35  14  10  360  2629
# 6      중랑구     18.5    3.06  16   6  558  4232
# 7      성북구    24.58    4.06  20  39  468  3667
# 8      강북구     23.6     3.9  13   4  389  3384
# 9      도봉구    20.65    3.41  14   4  396  2993
# 10     노원구    35.44    5.86  19   5  720  5864
# 11     은평구    29.71    4.91  16  11  574  4250
# 12    서대문구    17.63    2.91  14  20  518  3673
# 13     마포구    23.85    3.94  16  26  418  3281
# 14     양천구    17.41    2.88  18   3  563  4598
# 15     강서구    41.45    6.85  20  13  646  5087
# 16     구로구    20.12    3.32  16  10  629  4926
# 17     금천구    13.02    2.15  10   3  386  2912
# 18    영등포구    24.55    4.06  18  34  583  4922
# ...

# %%
area.rename(columns={"자치구별(2)" : '구별'}, inplace=True)
area.head()
# Out:
# 1     구별 면적 (km²) 구성비 (%)  행정  법정   소계    소계
# 0    종로구    23.91    3.95  17  87  279  1475
# 1     중구     9.96    1.65  15  74  253  1582
# 2    용산구    21.87    3.61  16  36  357  2601
# 3    성동구    16.82    2.78  17  17  471  3645
# 4    광진구    17.06    2.82  15   7  370  3012
# 5   동대문구    14.22    2.35  14  10  360  2629
# 6    중랑구     18.5    3.06  16   6  558  4232
# 7    성북구    24.58    4.06  20  39  468  3667
# 8    강북구     23.6     3.9  13   4  389  3384
# 9    도봉구    20.65    3.41  14   4  396  2993
# 10   노원구    35.44    5.86  19   5  720  5864
# 11   은평구    29.71    4.91  16  11  574  4250
# 12  서대문구    17.63    2.91  14  20  518  3673
# 13   마포구    23.85    3.94  16  26  418  3281
# 14   양천구    17.41    2.88  18   3  563  4598
# 15   강서구    41.45    6.85  20  13  646  5087
# 16   구로구    20.12    3.32  16  10  629  4926
# 17   금천구    13.02    2.15  10   3  386  2912
# 18  영등포구    24.55    4.06  18  34  583  4922
# 19   동작구    16.36     2.7  15   9  526  3518
# ...

# %%
area = area[['구별', '면적 (km²)', '구성비 (%)']]

# %% [markdown]
# ### concat

# %%
cctv_sum.head()
# Out:
#    자치구  CCTV 수량
# 0  강남구     7009
# 1  강동구     3191
# 2  강북구     2858
# 3  강서구     3481
# 4  관악구     5366

# %%
crime_state.head()
# Out:
#     구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0  강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1  강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2  강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3  강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4  관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
#
#      절도발생    절도검거  절도검거율    폭력발생    폭력검거  폭력검거율   평균검거율
# 0  2495.0  1207.0  48.38  3762.0  3259.0  86.63  77.862
# 1  1672.0   900.0  53.83  1872.0  1599.0  85.42  84.920
# 2   872.0   589.0  67.55  1773.0  1597.0  90.07  84.134
# 3  1991.0  1185.0  59.52  2401.0  2201.0  91.67  85.180
# 4  1966.0  1050.0  53.41  2567.0  2066.0  80.48  77.620

# %%
area.head()
# Out:
# 1   구별 면적 (km²) 구성비 (%)
# 0  종로구    23.91    3.95
# 1   중구     9.96    1.65
# 2  용산구    21.87    3.61
# 3  성동구    16.82    2.78
# 4  광진구    17.06    2.82

# %%
merge_crime = pd.merge(crime_state, cctv_sum, left_on='구별', right_on='자치구', how='inner')
merge_crime.drop(columns='자치구', inplace=True)
merge_crime.head()
# Out:
#       구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0    강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1    강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2    강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3    강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4    관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
# 5    광진구   6.0   5.0   83.33   0.0   0.0     NaN    230.0    174.0     75.65
# 6    구로구  11.0  11.0  100.00   8.0   9.0  100.00    217.0    145.0     66.82
# 7    금천구   2.0   1.0   50.00   3.0   3.0  100.00    127.0     87.0     68.50
# 8    노원구   3.0   3.0  100.00   3.0   1.0   33.33    180.0    151.0     83.89
# 9    도봉구   3.0   3.0  100.00   0.0   0.0     NaN     70.0     54.0     77.14
# 10  동대문구   4.0   4.0  100.00   2.0   2.0  100.00    125.0    106.0     84.80
# ...

# %%
merge_crime = pd.merge(merge_crime, area, on='구별')
merge_crime.head()
# Out:
#       구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0    강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1    강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2    강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3    강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4    관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
# 5    광진구   6.0   5.0   83.33   0.0   0.0     NaN    230.0    174.0     75.65
# 6    구로구  11.0  11.0  100.00   8.0   9.0  100.00    217.0    145.0     66.82
# 7    금천구   2.0   1.0   50.00   3.0   3.0  100.00    127.0     87.0     68.50
# 8    노원구   3.0   3.0  100.00   3.0   1.0   33.33    180.0    151.0     83.89
# 9    도봉구   3.0   3.0  100.00   0.0   0.0     NaN     70.0     54.0     77.14
# 10  동대문구   4.0   4.0  100.00   2.0   2.0  100.00    125.0    106.0     84.80
# ...

# %%
merge_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   구별                   25 non-null     object
#  1   살인발생                 25 non-null     float64
#  2   살인검거                 25 non-null     float64
#  3   살인검거율                25 non-null     float64
#  4   강도발생                 25 non-null     float64
#  5   강도검거                 25 non-null     float64
#  6   강도검거율                23 non-null     float64
#  7   강간,추행발생              25 non-null     float64
#  8   강간,추행검거              25 non-null     float64
#  9   강간,추행검거율             25 non-null     float64
#  10  절도발생                 25 non-null     float64
#  11  절도검거                 25 non-null     float64
#  12  절도검거율                25 non-null     float64
#  13  폭력발생                 25 non-null     float64
#  14  폭력검거                 25 non-null     float64
# ...

# %%
merge_crime['면적 (km²)'] = merge_crime['면적 (km²)'].astype(float) 
merge_crime['구성비 (%)'] = merge_crime['구성비 (%)'].astype(float)

# %%
merge_crime['면적 당 CCTV 대수(km² 당)'] = round((merge_crime['CCTV 수량'] / merge_crime['면적 (km²)']), 2)
merge_crime.head()
# Out:
#     구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0  강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1  강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2  강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3  강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4  관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
#
#    ...    절도검거  절도검거율    폭력발생    폭력검거  폭력검거율   평균검거율  CCTV 수량  면적 (km²)  \
# 0  ...  1207.0  48.38  3762.0  3259.0  86.63  77.862     7009     39.50
# 1  ...   900.0  53.83  1872.0  1599.0  85.42  84.920     3191     24.59
# 2  ...   589.0  67.55  1773.0  1597.0  90.07  84.134     2858     23.60
# 3  ...  1185.0  59.52  2401.0  2201.0  91.67  85.180     3481     41.45
# 4  ...  1050.0  53.41  2567.0  2066.0  80.48  77.620     5366     29.57
#
#    구성비 (%)  면적 당 CCTV 대수(km² 당)
# 0     6.53               177.44
# ...

# %% [markdown]
# ## data visualization

# %% [markdown]
# ### 구 면적 당 CCTV 대수

# %%
merge_crime_sorted = merge_crime.sort_values(by='면적 당 CCTV 대수(km² 당)', ascending=False)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='면적 당 CCTV 대수(km² 당)', palette='viridis', hue='구별')
plt.title("구 면적 당 CCTV 대수")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()

# %%
merge_crime['발생 총계'] = merge_crime['살인발생'] + merge_crime['강도발생'] + merge_crime['강간,추행발생'] + merge_crime['폭력발생'] + merge_crime['절도발생']
merge_crime['발생 총계'] = merge_crime['발생 총계'].astype(int)
merge_crime.head()
# Out:
#     구별  살인발생  살인검거   살인검거율  강도발생  강도검거   강도검거율  강간,추행발생  강간,추행검거  강간,추행검거율  \
# 0  강남구  12.0  10.0   83.33  11.0  10.0   90.91    667.0    534.0     80.06
# 1  강동구   5.0   6.0  100.00   5.0   5.0  100.00    157.0    134.0     85.35
# 2  강북구   5.0   4.0   80.00   5.0   6.0  100.00    177.0    147.0     83.05
# 3  강서구   3.0   3.0  100.00   7.0   7.0  100.00    261.0    195.0     74.71
# 4  관악구  10.0   8.0   80.00   9.0   8.0   88.89    327.0    279.0     85.32
#
#    ...  절도검거율    폭력발생    폭력검거  폭력검거율   평균검거율  CCTV 수량  면적 (km²)  구성비 (%)  \
# 0  ...  48.38  3762.0  3259.0  86.63  77.862     7009     39.50     6.53
# 1  ...  53.83  1872.0  1599.0  85.42  84.920     3191     24.59     4.06
# 2  ...  67.55  1773.0  1597.0  90.07  84.134     2858     23.60     3.90
# 3  ...  59.52  2401.0  2201.0  91.67  85.180     3481     41.45     6.85
# 4  ...  53.41  2567.0  2066.0  80.48  77.620     5366     29.57     4.89
#
#    면적 당 CCTV 대수(km² 당)  발생 총계
# 0               177.44   6947
# ...

# %%
merge_crime_sorted = merge_crime.sort_values(by='발생 총계', ascending=True)

plt.figure(figsize=(18, 10))
ax = sns.barplot(data=merge_crime_sorted, x='구별', y='발생 총계', palette='viridis', hue='구별')
plt.title("발생 총계")
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')
plt.xticks(rotation=45)
plt.show()
